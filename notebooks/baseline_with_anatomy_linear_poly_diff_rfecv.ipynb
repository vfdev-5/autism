# %% [markdown]
# # Baseline model based on anatomy features

# %% [markdown]
# Useful links :
#
# - https://brainder.org/2018/01/23/how-do-we-measure-thickness-area-and-volume-of-the-cerebral-cortex/
# - https://s3.us-east-2.amazonaws.com/brainder/publications/2010/winkler2010_thickness_area.pdf
#     - The results suggest that surface area and cortical thickness measurements should be considered separately and preferred over gray matter volumes for imaging genetic studies.

# %%
path = ".."

import sys
sys.path.insert(0, path)

# %%
import numpy as np
import pandas as pd

import matplotlib.pylab as plt
# %matplotlib inline
import seaborn as sns

# %%
from problem import get_train_data, get_test_data

data_train_, labels_train_ = get_train_data(path=path)
data_test_, labels_test_ = get_test_data(path=path)

# %% [markdown]
# ## Preprocess input data
#
# Join train and test

# %%
data_train = pd.concat([data_train_, pd.Series(labels_train_, index=data_train_.index, name='target')], axis=1)
data_test = pd.concat([data_test_, pd.Series(labels_test_, index=data_test_.index, name='target')], axis=1)

data_train.loc[:, 'is_train'] = 1
data_test.loc[:, 'is_train'] = 0

data = pd.concat([data_train, data_test], axis=0)

# %%
data['participants_sex'] = data['participants_sex'].map({'F': -1.0, 'M': +1.0}) 
accepted_anatomy = data['anatomy_select'].isin([1, 2])

# %%
data.shape
# Out:
# (1150, 222)

# %% [markdown]
# Remove poor QA data

# %%
data1 = data[accepted_anatomy].copy()
data1.shape
# Out:
# (1031, 222)

# %%
import re 

left_cols = sorted([col for col in data1.columns if col.startswith('anatomy') and re.match(r".+(lh|Left)", col)])

left_cols.remove('anatomy_Left-WM-hypointensities')
left_cols.remove('anatomy_Left-non-WM-hypointensities')

right_cols = []
for c in left_cols:
    if "lh" in c:
        c = c.replace("lh", "rh")
    elif "Left" in c:
        c = c.replace("Left", "Right")
    right_cols.append(c)

anatomy_LR_diff_cols = [(c1, c2) for c1, c2 in zip(left_cols, right_cols)]

# %%
to_remove_anatomy_features = [
    'anatomy_Left-WM-hypointensities',
    'anatomy_Left-non-WM-hypointensities',
    'anatomy_Right-WM-hypointensities',
    'anatomy_Right-non-WM-hypointensities',
    'anatomy_5th-Ventricle', 
    'anatomy_non-WM-hypointensities',
    
    # Correlated with others
    'anatomy_EstimatedTotalIntraCranialVol',
    'anatomy_SupraTentorialVolNotVentVox',
#     'anatomy_SubCortGrayVol',
#     'anatomy_TotalGrayVol',
    
    # Remove correlated L <-> R
    'anatomy_Right-Caudate',
    'anatomy_Right-Cerebellum-Cortex',
    'anatomy_Right-Putamen',
    'anatomy_Right-VentralDC',
    'anatomy_rhCerebralWhiteMatterVol',
    'anatomy_rhCortexVol',
    'anatomy_rhSurfaceHoles',
    'anatomy_rh_MeanThickness_thickness',
    'anatomy_rh_WhiteSurfArea_area',
    'anatomy_rh_superiorparietal_thickness',
]

compute_diff_and_remove_first_anatomy_features = [
    ('anatomy_SubCortGrayVol', 'anatomy_BrainSegVol'),    
    ('anatomy_TotalGrayVol', 'anatomy_CortexVol'),    
]

# %%
anatomy_cols = [col for col in data1.columns if col.startswith('anatomy')]

anatomy_cols.remove('anatomy_select')

for c in to_remove_anatomy_features:
    anatomy_cols.remove(c)

participant_cols = [col for col in data1.columns if col.startswith('participant')]
participant_cols.remove('participants_site')

# %%
len(anatomy_cols)
# Out:
# 189

# %%
anatomy_diff_cols = []
to_remove_anatomy_diff_cols = []


for c1, c2 in anatomy_LR_diff_cols:
    data1.loc[:, "({} - {})".format(c1, c2)] = data1[c1] - data1[c2]
    anatomy_diff_cols.append("({} - {})".format(c1, c2))

    
for c1, c2 in compute_diff_and_remove_first_anatomy_features:
    data1.loc[:, "({} - {})".format(c1, c2)] = data1[c1] - data1[c2]
    anatomy_diff_cols.append("({} - {})".format(c1, c2))
    to_remove_anatomy_diff_cols.append(c1)

for c in to_remove_anatomy_diff_cols:
    anatomy_cols.remove(c)

# %%
len(anatomy_diff_cols)
# Out:
# 89

# %%
data1.shape
# Out:
# (1031, 311)

# %% [markdown]
# Rescale features:
#
# - age -> age / 100 in [0.0, 1.0]

# %%
data1.loc[:, 'participants_age'] = data1['participants_age'] / 100.0

# %% [markdown]
# Compute inversions

# %%
inverted_cols = []

for c in anatomy_cols + anatomy_diff_cols + ["participants_age", ]:
    data1.loc[:, "1/({})".format(c)] = 1.0 / (data1[c] + 1e-10)
    inverted_cols.append("1/({})".format(c))

# %%
data1.head()
# Out:
#                       participants_site  participants_sex  participants_age  \
# subject_id
# 1932355398536124106                   5              -1.0          0.093014
# 5174041730092253771                  19               1.0          0.290000
# 10219322676643534800                 19              -1.0          0.450000
# 10645466564919190227                  5              -1.0          0.092164
# 14512541342641936232                 28               1.0          0.150500
#
#                       anatomy_lh_bankssts_area  \
# subject_id
# 1932355398536124106                      977.0
# 5174041730092253771                     1279.0
# 10219322676643534800                     926.0
# 10645466564919190227                     983.0
# 14512541342641936232                    1488.0
#
#                       anatomy_lh_caudalanteriorcingulate_area  \
# subject_id
# 1932355398536124106                                     427.0
# 5174041730092253771                                     730.0
# 10219322676643534800                                    446.0
# 10645466564919190227                                    588.0
# 14512541342641936232                                    593.0
#
#                       anatomy_lh_caudalmiddlefrontal_area  \
# subject_id
# 1932355398536124106                                1884.0
# 5174041730092253771                                2419.0
# 10219322676643534800                               1897.0
# 10645466564919190227                               2479.0
# 14512541342641936232                               2309.0
#
#                       anatomy_lh_cuneus_area  anatomy_lh_entorhinal_area  \
# subject_id
# 1932355398536124106                   1449.0                       463.0
# 5174041730092253771                   1611.0                       467.0
# 10219322676643534800                  2135.0                       570.0
# 10645466564919190227                  1312.0                       525.0
# 14512541342641936232                  1829.0                       726.0
#
#                       anatomy_lh_fusiform_area  \
# subject_id
# 1932355398536124106                     2790.0
# 5174041730092253771                     3562.0
# 10219322676643534800                    3064.0
# 10645466564919190227                    3766.0
# 14512541342641936232                    3720.0
#
#                       anatomy_lh_inferiorparietal_area          ...           \
# subject_id                                                      ...
# 1932355398536124106                             4091.0          ...
# 5174041730092253771                             5380.0          ...
# 10219322676643534800                            4834.0          ...
# 10645466564919190227                            5091.0          ...
# 14512541342641936232                            5432.0          ...
#
#                       1/((anatomy_lh_superiortemporal_thickness - anatomy_rh_superiortemporal_thickness))  \
# subject_id
# 1932355398536124106                                          166.666664
# 5174041730092253771                                          -35.714286
# 10219322676643534800                                         -83.333334
# 10645466564919190227                                         -18.181818
# 14512541342641936232                                          -9.345794
#
#                       1/((anatomy_lh_supramarginal_area - anatomy_rh_supramarginal_area))  \
# subject_id
# 1932355398536124106                                           -0.011494
# 5174041730092253771                                            0.001361
# 10219322676643534800                                           0.001842
# 10645466564919190227                                           0.001458
# 14512541342641936232                                           0.004274
#
#                       1/((anatomy_lh_supramarginal_thickness - anatomy_rh_supramarginal_thickness))  \
# subject_id
# 1932355398536124106                                          -13.333333
# 5174041730092253771                                          -25.000000
# 10219322676643534800                                          18.867924
# 10645466564919190227                                          -3.571429
# 14512541342641936232                                          27.027027
#
#                       1/((anatomy_lh_temporalpole_area - anatomy_rh_temporalpole_area))  \
# subject_id
# 1932355398536124106                                           -0.028571
# 5174041730092253771                                           -0.014085
# 10219322676643534800                                          -0.037037
# 10645466564919190227                                           0.142857
# 14512541342641936232                                           0.142857
#
#                       1/((anatomy_lh_temporalpole_thickness - anatomy_rh_temporalpole_thickness))  \
# subject_id
# 1932355398536124106                                           10.989011
# 5174041730092253771                                            4.201681
# 10219322676643534800                                         -29.411765
# 10645466564919190227                                           2.680965
# 14512541342641936232                                           8.264463
#
#                       1/((anatomy_lh_transversetemporal_area - anatomy_rh_transversetemporal_area))  \
# subject_id
# 1932355398536124106                                            0.010000
# 5174041730092253771                                            0.006711
# 10219322676643534800                                           0.008000
# 10645466564919190227                                           0.008475
# 14512541342641936232                                           0.005319
#
#                       1/((anatomy_lh_transversetemporal_thickness - anatomy_rh_transversetemporal_thickness))  \
# subject_id
# 1932355398536124106                                            5.128205
# 5174041730092253771                                            5.882353
# 10219322676643534800                                         -33.333333
# 10645466564919190227                                         -13.513514
# 14512541342641936232                                          -3.448276
#
#                       1/((anatomy_SubCortGrayVol - anatomy_BrainSegVol))  \
# subject_id
# 1932355398536124106                                       -9.802163e-07
# 5174041730092253771                                       -7.816976e-07
# 10219322676643534800                                      -9.670422e-07
# 10645466564919190227                                      -8.719460e-07
# 14512541342641936232                                      -8.261698e-07
#
#                       1/((anatomy_TotalGrayVol - anatomy_CortexVol))  \
# subject_id
# 1932355398536124106                                         0.000007
# 5174041730092253771                                         0.000005
# 10219322676643534800                                        0.000006
# 10645466564919190227                                        0.000006
# 14512541342641936232                                        0.000005
#
#                       1/(participants_age)
# subject_id
# 1932355398536124106              10.751105
# 5174041730092253771               3.448276
# 10219322676643534800              2.222222
# 10645466564919190227             10.850178
# 14512541342641936232              6.644518
#
# [5 rows x 588 columns]

# %%
data1.shape
# Out:
# (1031, 588)

# %% [markdown]
# Polynomial 2nd degree

# %%
train_columns1 = anatomy_cols + anatomy_diff_cols + ['participants_age', ]
train_columns2 = inverted_cols
train_columns = train_columns1 + train_columns2
len(train_columns1), len(train_columns2)
# Out:
# (277, 277)

# %%
data_ = data1[train_columns].values
data_.shape
# Out:
# (1031, 554)

# %%
pairs_columns = []

n1 = len(train_columns1) * (len(train_columns1) - 1) // 2
n2 = (len(train_columns1) - 1) * len(train_columns2)

pairs_data = np.zeros((len(data_), n1 + n2))
offset = len(train_columns1)

c = 0
for i, f1 in enumerate(train_columns1):
    for j, f2 in enumerate(train_columns1):
        if i < j:
            pairs_columns.append("{} x {}".format(f1, f2))
            pairs_data[:, c] = data_[:, i] * data_[:, j]
            c += 1


    for j, f2 in enumerate(train_columns2):
        if i != j:
            pairs_columns.append("{} x {}".format(f1, f2))
            pairs_data[:, c] = data_[:, i] * data_[:, offset + j]
            c += 1

# %%
pairs_df = pd.DataFrame(pairs_data, columns=pairs_columns, index=data1.index)

# %%
pairs_columns = pairs_df.columns.values.tolist()
pairs_df.shape
# Out:
# (1031, 114678)

# %%
data2 = pd.concat([data1, pairs_df], axis=1)

# %%
data2.shape
# Out:
# (1031, 115266)

# %%
train_columns = anatomy_cols + anatomy_diff_cols + participant_cols + inverted_cols + pairs_columns
len(train_columns)
# Out:
# 115233

# %%
data2[train_columns].head()
# Out:
#                       anatomy_lh_bankssts_area  \
# subject_id
# 1932355398536124106                      977.0
# 5174041730092253771                     1279.0
# 10219322676643534800                     926.0
# 10645466564919190227                     983.0
# 14512541342641936232                    1488.0
#
#                       anatomy_lh_caudalanteriorcingulate_area  \
# subject_id
# 1932355398536124106                                     427.0
# 5174041730092253771                                     730.0
# 10219322676643534800                                    446.0
# 10645466564919190227                                    588.0
# 14512541342641936232                                    593.0
#
#                       anatomy_lh_caudalmiddlefrontal_area  \
# subject_id
# 1932355398536124106                                1884.0
# 5174041730092253771                                2419.0
# 10219322676643534800                               1897.0
# 10645466564919190227                               2479.0
# 14512541342641936232                               2309.0
#
#                       anatomy_lh_cuneus_area  anatomy_lh_entorhinal_area  \
# subject_id
# 1932355398536124106                   1449.0                       463.0
# 5174041730092253771                   1611.0                       467.0
# 10219322676643534800                  2135.0                       570.0
# 10645466564919190227                  1312.0                       525.0
# 14512541342641936232                  1829.0                       726.0
#
#                       anatomy_lh_fusiform_area  \
# subject_id
# 1932355398536124106                     2790.0
# 5174041730092253771                     3562.0
# 10219322676643534800                    3064.0
# 10645466564919190227                    3766.0
# 14512541342641936232                    3720.0
#
#                       anatomy_lh_inferiorparietal_area  \
# subject_id
# 1932355398536124106                             4091.0
# 5174041730092253771                             5380.0
# 10219322676643534800                            4834.0
# 10645466564919190227                            5091.0
# 14512541342641936232                            5432.0
#
#                       anatomy_lh_inferiortemporal_area  \
# subject_id
# 1932355398536124106                             3305.0
# 5174041730092253771                             3555.0
# 10219322676643534800                            2602.0
# 10645466564919190227                            3433.0
# 14512541342641936232                            3956.0
#
#                       anatomy_lh_isthmuscingulate_area  \
# subject_id
# 1932355398536124106                              897.0
# 5174041730092253771                             1155.0
# 10219322676643534800                            1171.0
# 10645466564919190227                            1028.0
# 14512541342641936232                            1033.0
#
#                       anatomy_lh_lateraloccipital_area  \
# subject_id
# 1932355398536124106                             4406.0
# 5174041730092253771                             5611.0
# 10219322676643534800                            6395.0
# 10645466564919190227                            5405.0
# 14512541342641936232                            5644.0
#
#                                                     ...                                  \
# subject_id                                          ...
# 1932355398536124106                                 ...
# 5174041730092253771                                 ...
# 10219322676643534800                                ...
# 10645466564919190227                                ...
# 14512541342641936232                                ...
#
#                       participants_age x 1/((anatomy_lh_superiortemporal_area - anatomy_rh_superiortemporal_area))  \
# subject_id
# 1932355398536124106                                           -0.001000
# 5174041730092253771                                            0.000566
# 10219322676643534800                                           0.001765
# 10645466564919190227                                           0.000171
# 14512541342641936232                                           0.000340
#
#                       participants_age x 1/((anatomy_lh_superiortemporal_thickness - anatomy_rh_superiortemporal_thickness))  \
# subject_id
# 1932355398536124106                                           15.502283
# 5174041730092253771                                          -10.357143
# 10219322676643534800                                         -37.500000
# 10645466564919190227                                          -1.675716
# 14512541342641936232                                          -1.406542
#
#                       participants_age x 1/((anatomy_lh_supramarginal_area - anatomy_rh_supramarginal_area))  \
# subject_id
# 1932355398536124106                                           -0.001069
# 5174041730092253771                                            0.000395
# 10219322676643534800                                           0.000829
# 10645466564919190227                                           0.000134
# 14512541342641936232                                           0.000643
#
#                       participants_age x 1/((anatomy_lh_supramarginal_thickness - anatomy_rh_supramarginal_thickness))  \
# subject_id
# 1932355398536124106                                           -1.240183
# 5174041730092253771                                           -7.250000
# 10219322676643534800                                           8.490566
# 10645466564919190227                                          -0.329159
# 14512541342641936232                                           4.067568
#
#                       participants_age x 1/((anatomy_lh_temporalpole_area - anatomy_rh_temporalpole_area))  \
# subject_id
# 1932355398536124106                                           -0.002658
# 5174041730092253771                                           -0.004085
# 10219322676643534800                                          -0.016667
# 10645466564919190227                                           0.013166
# 14512541342641936232                                           0.021500
#
#                       participants_age x 1/((anatomy_lh_temporalpole_thickness - anatomy_rh_temporalpole_thickness))  \
# subject_id
# 1932355398536124106                                            1.022129
# 5174041730092253771                                            1.218487
# 10219322676643534800                                         -13.235294
# 10645466564919190227                                           0.247090
# 14512541342641936232                                           1.243802
#
#                       participants_age x 1/((anatomy_lh_transversetemporal_area - anatomy_rh_transversetemporal_area))  \
# subject_id
# 1932355398536124106                                            0.000930
# 5174041730092253771                                            0.001946
# 10219322676643534800                                           0.003600
# 10645466564919190227                                           0.000781
# 14512541342641936232                                           0.000801
#
#                       participants_age x 1/((anatomy_lh_transversetemporal_thickness - anatomy_rh_transversetemporal_thickness))  \
# subject_id
# 1932355398536124106                                            0.476993
# 5174041730092253771                                            1.705882
# 10219322676643534800                                         -15.000000
# 10645466564919190227                                          -1.245465
# 14512541342641936232                                          -0.518966
#
#                       participants_age x 1/((anatomy_SubCortGrayVol - anatomy_BrainSegVol))  \
# subject_id
# 1932355398536124106                                       -9.117354e-08
# 5174041730092253771                                       -2.266923e-07
# 10219322676643534800                                      -4.351690e-07
# 10645466564919190227                                      -8.036237e-08
# 14512541342641936232                                      -1.243385e-07
#
#                       participants_age x 1/((anatomy_TotalGrayVol - anatomy_CortexVol))
# subject_id
# 1932355398536124106                                        6.223400e-07
# 5174041730092253771                                        1.547253e-06
# 10219322676643534800                                       2.865913e-06
# 10645466564919190227                                       5.429131e-07
# 14512541342641936232                                       7.986754e-07
#
# [5 rows x 115233 columns]

# %% [markdown]
# ### Recursive feature elimination with CV

# %%
from sklearn.feature_selection import RFECV
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import StratifiedKFold

# %%
data3 = data2[train_columns + ['target', ]].copy()

# %%
scaler = StandardScaler()

cols = anatomy_cols + anatomy_diff_cols + inverted_cols + pairs_columns

data3.loc[:, cols] = scaler.fit_transform(data3[cols])

# %%
n_jobs=1
seed = 42

log_reg = LogisticRegression(random_state=seed)

# %%
rfecv = RFECV(estimator=log_reg, step=0.15, cv=StratifiedKFold(n_splits=4), scoring='roc_auc', n_jobs=8, verbose=True)
rfecv.fit(data3[train_columns], data3['target'])
# Out:
# Fitting estimator with 115233 features.
# Fitting estimator with 115233 features.
# Fitting estimator with 115233 features.
# Fitting estimator with 115233 features.
# Fitting estimator with 97949 features.
# Fitting estimator with 97949 features.
# Fitting estimator with 97949 features.
# Fitting estimator with 97949 features.
# Fitting estimator with 80665 features.
# Fitting estimator with 80665 features.
# Fitting estimator with 80665 features.
# Fitting estimator with 80665 features.
# Fitting estimator with 63381 features.
# Fitting estimator with 63381 features.
# Fitting estimator with 63381 features.
# Fitting estimator with 63381 features.
# Fitting estimator with 46097 features.
# Fitting estimator with 46097 features.
# Fitting estimator with 46097 features.
# Fitting estimator with 46097 features.
# Fitting estimator with 28813 features.
# Fitting estimator with 28813 features.
# Fitting estimator with 28813 features.
# Fitting estimator with 28813 features.
# Fitting estimator with 11529 features.
# Fitting estimator with 11529 features.
# Fitting estimator with 11529 features.
# Fitting estimator with 11529 features.
# RFECV(cv=StratifiedKFold(n_splits=4, random_state=None, shuffle=False),
#    estimator=LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=42, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False),
#    n_jobs=8, scoring='roc_auc', step=0.15, verbose=True)

# %%
rfecv.n_features_
# Out:
# 46097

# %%
rfecv.support_
# Out:
# (115233,)

# %%
features = [i for i in range(len(rfecv.grid_scores_))] 
features
# Out:
# [0, 1, 2, 3, 4, 5, 6, 7]

# %%
print("Optimal number of features : %d" % rfecv.n_features_)

# Plot number of features VS. cross-validation scores
plt.figure()
plt.ylabel("Cross validation score (nb of correct classifications)")
plt.plot(features, rfecv.grid_scores_)
plt.show()
# Out:
# Optimal number of features : 46097

# %%
selected_columns = np.array(train_columns)[rfecv.support_].tolist()

# %%
selected_columns
# Out:
# ['anatomy_lh_parstriangularis_area',
#  'anatomy_lh_pericalcarine_area',
#  'anatomy_lh_precuneus_area',
#  'anatomy_lh_superiorfrontal_area',
#  'anatomy_lh_superiorparietal_area',
#  'anatomy_lh_supramarginal_area',
#  'anatomy_rh_inferiortemporal_area',
#  'anatomy_rh_parsopercularis_area',
#  'anatomy_rh_parstriangularis_area',
#  'anatomy_rh_pericalcarine_area',
#  'anatomy_rh_rostralmiddlefrontal_area',
#  'anatomy_rh_superiorfrontal_area',
#  'anatomy_rh_superiorparietal_area',
#  'anatomy_rh_supramarginal_area',
#  'anatomy_lh_fusiform_thickness',
#  'anatomy_lh_lateraloccipital_thickness',
#  'anatomy_lh_medialorbitofrontal_thickness',
#  'anatomy_lh_middletemporal_thickness',
#  'anatomy_lh_paracentral_thickness',
#  'anatomy_lh_superiorfrontal_thickness',
#  'anatomy_lh_superiortemporal_thickness',
#  'anatomy_rh_entorhinal_thickness',
#  'anatomy_rh_lateraloccipital_thickness',
#  'anatomy_rh_middletemporal_thickness',
#  'anatomy_rh_paracentral_thickness',
#  'anatomy_rh_precuneus_thickness',
#  'anatomy_rh_rostralmiddlefrontal_thickness',
#  'anatomy_rh_superiorfrontal_thickness',
#  'anatomy_rh_superiortemporal_thickness',
#  'anatomy_Brain-Stem',
#  'anatomy_Left-Amygdala',
#  'anatomy_CC_Central',
#  'anatomy_CC_Mid_Anterior',
#  'anatomy_CC_Anterior',
#  'anatomy_MaskVol',
#  'anatomy_BrainSegVol-to-eTIV',
#  '(anatomy_Left-Amygdala - anatomy_Right-Amygdala)',
#  '(anatomy_lh_MeanThickness_thickness - anatomy_rh_MeanThickness_thickness)',
#  '(anatomy_lh_bankssts_area - anatomy_rh_bankssts_area)',
#  '(anatomy_lh_entorhinal_thickness - anatomy_rh_entorhinal_thickness)',
#  '(anatomy_lh_rostralmiddlefrontal_thickness - anatomy_rh_rostralmiddlefrontal_thickness)',
#  'participants_sex',
#  'participants_age',
#  '1/(anatomy_lh_bankssts_area)',
#  '1/(anatomy_lh_cuneus_area)',
#  '1/(anatomy_lh_inferiorparietal_area)',
#  '1/(anatomy_lh_lingual_area)',
#  '1/(anatomy_lh_parsorbitalis_area)',
#  '1/(anatomy_lh_precentral_area)',
#  '1/(anatomy_lh_rostralmiddlefrontal_area)',
#  '1/(anatomy_lh_supramarginal_area)',
#  '1/(anatomy_lh_frontalpole_area)',
#  '1/(anatomy_lh_temporalpole_area)',
#  '1/(anatomy_rh_bankssts_area)',
#  '1/(anatomy_rh_caudalanteriorcingulate_area)',
#  '1/(anatomy_rh_cuneus_area)',
#  '1/(anatomy_rh_entorhinal_area)',
#  '1/(anatomy_rh_inferiorparietal_area)',
#  '1/(anatomy_rh_inferiortemporal_area)',
#  '1/(anatomy_rh_isthmuscingulate_area)',
#  '1/(anatomy_rh_lingual_area)',
#  '1/(anatomy_rh_paracentral_area)',
#  '1/(anatomy_rh_parsopercularis_area)',
#  '1/(anatomy_rh_parstriangularis_area)',
#  '1/(anatomy_rh_posteriorcingulate_area)',
#  '1/(anatomy_rh_precentral_area)',
#  '1/(anatomy_rh_rostralanteriorcingulate_area)',
#  '1/(anatomy_rh_rostralmiddlefrontal_area)',
#  '1/(anatomy_rh_superiortemporal_area)',
#  '1/(anatomy_rh_supramarginal_area)',
#  '1/(anatomy_rh_transversetemporal_area)',
#  '1/(anatomy_lh_caudalanteriorcingulate_thickness)',
#  '1/(anatomy_lh_entorhinal_thickness)',
#  '1/(anatomy_lh_fusiform_thickness)',
#  '1/(anatomy_lh_isthmuscingulate_thickness)',
#  '1/(anatomy_lh_lateralorbitofrontal_thickness)',
#  '1/(anatomy_lh_middletemporal_thickness)',
#  '1/(anatomy_lh_parsorbitalis_thickness)',
#  '1/(anatomy_lh_posteriorcingulate_thickness)',
#  '1/(anatomy_lh_rostralanteriorcingulate_thickness)',
#  '1/(anatomy_lh_superiorfrontal_thickness)',
#  '1/(anatomy_lh_superiortemporal_thickness)',
#  '1/(anatomy_lh_temporalpole_thickness)',
#  '1/(anatomy_rh_bankssts_thickness)',
#  '1/(anatomy_rh_entorhinal_thickness)',
#  '1/(anatomy_rh_fusiform_thickness)',
#  '1/(anatomy_rh_isthmuscingulate_thickness)',
#  '1/(anatomy_rh_lateralorbitofrontal_thickness)',
#  '1/(anatomy_rh_lingual_thickness)',
#  '1/(anatomy_rh_middletemporal_thickness)',
#  '1/(anatomy_rh_parstriangularis_thickness)',
#  '1/(anatomy_rh_precuneus_thickness)',
#  '1/(anatomy_rh_rostralmiddlefrontal_thickness)',
#  '1/(anatomy_rh_superiorfrontal_thickness)',
#  '1/(anatomy_rh_superiortemporal_thickness)',
#  '1/(anatomy_rh_temporalpole_thickness)',
#  '1/(anatomy_rh_transversetemporal_thickness)',
#  '1/(anatomy_Left-Lateral-Ventricle)',
#  '1/(anatomy_Left-Cerebellum-Cortex)',
#  '1/(anatomy_Left-Pallidum)',
#  '1/(anatomy_3rd-Ventricle)',
#  '1/(anatomy_4th-Ventricle)',
#  '1/(anatomy_Left-Amygdala)',
#  '1/(anatomy_CSF)',
#  '1/(anatomy_Left-Accumbens-area)',
#  '1/(anatomy_Left-VentralDC)',
#  '1/(anatomy_Right-Inf-Lat-Vent)',
#  '1/(anatomy_Right-vessel)',
#  '1/(anatomy_CC_Anterior)',
#  '1/(anatomy_lhCerebralWhiteMatterVol)',
#  '1/(anatomy_CerebralWhiteMatterVol)',
#  '1/(anatomy_MaskVol)',
#  '1/(anatomy_MaskVol-to-eTIV)',
#  '1/((anatomy_Left-Caudate - anatomy_Right-Caudate))',
#  '1/((anatomy_Left-Putamen - anatomy_Right-Putamen))',
#  '1/((anatomy_lh_MeanThickness_thickness - anatomy_rh_MeanThickness_thickness))',
#  '1/((anatomy_lh_bankssts_area - anatomy_rh_bankssts_area))',
#  '1/((anatomy_lh_bankssts_thickness - anatomy_rh_bankssts_thickness))',
#  '1/((anatomy_lh_inferiorparietal_area - anatomy_rh_inferiorparietal_area))',
#  '1/((anatomy_lh_isthmuscingulate_thickness - anatomy_rh_isthmuscingulate_thickness))',
#  '1/((anatomy_lh_medialorbitofrontal_area - anatomy_rh_medialorbitofrontal_area))',
#  '1/((anatomy_lh_paracentral_area - anatomy_rh_paracentral_area))',
#  '1/((anatomy_lh_parsopercularis_thickness - anatomy_rh_parsopercularis_thickness))',
#  '1/((anatomy_lh_pericalcarine_thickness - anatomy_rh_pericalcarine_thickness))',
#  '1/((anatomy_lh_posteriorcingulate_area - anatomy_rh_posteriorcingulate_area))',
#  '1/((anatomy_lh_precuneus_area - anatomy_rh_precuneus_area))',
#  '1/((anatomy_TotalGrayVol - anatomy_CortexVol))',
#  '1/(participants_age)',
#  'anatomy_lh_bankssts_area x anatomy_lh_caudalanteriorcingulate_area',
#  'anatomy_lh_bankssts_area x anatomy_lh_caudalmiddlefrontal_area',
#  'anatomy_lh_bankssts_area x anatomy_lh_medialorbitofrontal_area',
#  'anatomy_lh_bankssts_area x anatomy_lh_middletemporal_area',
#  'anatomy_lh_bankssts_area x anatomy_lh_paracentral_area',
#  'anatomy_lh_bankssts_area x anatomy_lh_pericalcarine_area',
#  'anatomy_lh_bankssts_area x anatomy_lh_precentral_area',
#  'anatomy_lh_bankssts_area x anatomy_lh_rostralmiddlefrontal_area',
#  'anatomy_lh_bankssts_area x anatomy_lh_transversetemporal_area',
#  'anatomy_lh_bankssts_area x anatomy_rh_bankssts_area',
#  'anatomy_lh_bankssts_area x anatomy_rh_caudalanteriorcingulate_area',
#  'anatomy_lh_bankssts_area x anatomy_rh_entorhinal_area',
#  'anatomy_lh_bankssts_area x anatomy_rh_fusiform_area',
#  'anatomy_lh_bankssts_area x anatomy_rh_lateralorbitofrontal_area',
#  'anatomy_lh_bankssts_area x anatomy_rh_pericalcarine_area',
#  'anatomy_lh_bankssts_area x anatomy_rh_rostralmiddlefrontal_area',
#  'anatomy_lh_bankssts_area x anatomy_rh_superiortemporal_area',
#  'anatomy_lh_bankssts_area x anatomy_lh_caudalanteriorcingulate_thickness',
#  'anatomy_lh_bankssts_area x anatomy_lh_entorhinal_thickness',
#  'anatomy_lh_bankssts_area x anatomy_lh_inferiortemporal_thickness',
#  'anatomy_lh_bankssts_area x anatomy_lh_middletemporal_thickness',
#  'anatomy_lh_bankssts_area x anatomy_lh_paracentral_thickness',
#  'anatomy_lh_bankssts_area x anatomy_lh_posteriorcingulate_thickness',
#  'anatomy_lh_bankssts_area x anatomy_lh_superiorparietal_thickness',
#  'anatomy_lh_bankssts_area x anatomy_lh_frontalpole_thickness',
#  'anatomy_lh_bankssts_area x anatomy_rh_caudalanteriorcingulate_thickness',
#  'anatomy_lh_bankssts_area x anatomy_rh_caudalmiddlefrontal_thickness',
#  'anatomy_lh_bankssts_area x anatomy_rh_inferiorparietal_thickness',
#  'anatomy_lh_bankssts_area x anatomy_rh_paracentral_thickness',
#  'anatomy_lh_bankssts_area x anatomy_rh_postcentral_thickness',
#  'anatomy_lh_bankssts_area x anatomy_rh_frontalpole_thickness',
#  'anatomy_lh_bankssts_area x anatomy_Left-Inf-Lat-Vent',
#  'anatomy_lh_bankssts_area x anatomy_Left-Cerebellum-White-Matter',
#  'anatomy_lh_bankssts_area x anatomy_Left-Caudate',
#  'anatomy_lh_bankssts_area x anatomy_3rd-Ventricle',
#  'anatomy_lh_bankssts_area x anatomy_4th-Ventricle',
#  'anatomy_lh_bankssts_area x anatomy_Left-vessel',
#  'anatomy_lh_bankssts_area x anatomy_Right-Inf-Lat-Vent',
#  'anatomy_lh_bankssts_area x anatomy_Right-choroid-plexus',
#  'anatomy_lh_bankssts_area x anatomy_WM-hypointensities',
#  'anatomy_lh_bankssts_area x anatomy_Optic-Chiasm',
#  'anatomy_lh_bankssts_area x anatomy_CC_Posterior',
#  'anatomy_lh_bankssts_area x anatomy_CC_Mid_Anterior',
#  'anatomy_lh_bankssts_area x anatomy_CC_Anterior',
#  'anatomy_lh_bankssts_area x (anatomy_Left-Cerebellum-Cortex - anatomy_Right-Cerebellum-Cortex)',
#  'anatomy_lh_bankssts_area x (anatomy_Left-Cerebellum-White-Matter - anatomy_Right-Cerebellum-White-Matter)',
#  'anatomy_lh_bankssts_area x (anatomy_Left-Inf-Lat-Vent - anatomy_Right-Inf-Lat-Vent)',
#  'anatomy_lh_bankssts_area x (anatomy_Left-Lateral-Ventricle - anatomy_Right-Lateral-Ventricle)',
#  'anatomy_lh_bankssts_area x (anatomy_Left-Thalamus-Proper - anatomy_Right-Thalamus-Proper)',
#  'anatomy_lh_bankssts_area x (anatomy_Left-VentralDC - anatomy_Right-VentralDC)',
#  'anatomy_lh_bankssts_area x (anatomy_Left-vessel - anatomy_Right-vessel)',
#  'anatomy_lh_bankssts_area x (anatomy_lhCortexVol - anatomy_rhCortexVol)',
#  'anatomy_lh_bankssts_area x (anatomy_lhSurfaceHoles - anatomy_rhSurfaceHoles)',
#  'anatomy_lh_bankssts_area x (anatomy_lh_MeanThickness_thickness - anatomy_rh_MeanThickness_thickness)',
#  'anatomy_lh_bankssts_area x (anatomy_lh_WhiteSurfArea_area - anatomy_rh_WhiteSurfArea_area)',
#  'anatomy_lh_bankssts_area x (anatomy_lh_bankssts_area - anatomy_rh_bankssts_area)',
#  'anatomy_lh_bankssts_area x (anatomy_lh_bankssts_thickness - anatomy_rh_bankssts_thickness)',
#  'anatomy_lh_bankssts_area x (anatomy_lh_caudalmiddlefrontal_area - anatomy_rh_caudalmiddlefrontal_area)',
#  'anatomy_lh_bankssts_area x (anatomy_lh_caudalmiddlefrontal_thickness - anatomy_rh_caudalmiddlefrontal_thickness)',
#  'anatomy_lh_bankssts_area x (anatomy_lh_cuneus_area - anatomy_rh_cuneus_area)',
#  'anatomy_lh_bankssts_area x (anatomy_lh_entorhinal_area - anatomy_rh_entorhinal_area)',
#  'anatomy_lh_bankssts_area x (anatomy_lh_entorhinal_thickness - anatomy_rh_entorhinal_thickness)',
#  'anatomy_lh_bankssts_area x (anatomy_lh_frontalpole_area - anatomy_rh_frontalpole_area)',
#  'anatomy_lh_bankssts_area x (anatomy_lh_fusiform_area - anatomy_rh_fusiform_area)',
#  'anatomy_lh_bankssts_area x (anatomy_lh_inferiorparietal_area - anatomy_rh_inferiorparietal_area)',
#  'anatomy_lh_bankssts_area x (anatomy_lh_inferiorparietal_thickness - anatomy_rh_inferiorparietal_thickness)',
#  'anatomy_lh_bankssts_area x (anatomy_lh_inferiortemporal_thickness - anatomy_rh_inferiortemporal_thickness)',
#  'anatomy_lh_bankssts_area x (anatomy_lh_insula_area - anatomy_rh_insula_area)',
#  'anatomy_lh_bankssts_area x (anatomy_lh_insula_thickness - anatomy_rh_insula_thickness)',
#  'anatomy_lh_bankssts_area x (anatomy_lh_isthmuscingulate_area - anatomy_rh_isthmuscingulate_area)',
#  'anatomy_lh_bankssts_area x (anatomy_lh_lateraloccipital_thickness - anatomy_rh_lateraloccipital_thickness)',
#  'anatomy_lh_bankssts_area x (anatomy_lh_lateralorbitofrontal_area - anatomy_rh_lateralorbitofrontal_area)',
#  'anatomy_lh_bankssts_area x (anatomy_lh_lingual_thickness - anatomy_rh_lingual_thickness)',
#  'anatomy_lh_bankssts_area x (anatomy_lh_medialorbitofrontal_area - anatomy_rh_medialorbitofrontal_area)',
#  'anatomy_lh_bankssts_area x (anatomy_lh_medialorbitofrontal_thickness - anatomy_rh_medialorbitofrontal_thickness)',
#  'anatomy_lh_bankssts_area x (anatomy_lh_middletemporal_area - anatomy_rh_middletemporal_area)',
#  'anatomy_lh_bankssts_area x (anatomy_lh_paracentral_area - anatomy_rh_paracentral_area)',
#  'anatomy_lh_bankssts_area x (anatomy_lh_parahippocampal_thickness - anatomy_rh_parahippocampal_thickness)',
#  'anatomy_lh_bankssts_area x (anatomy_lh_parsorbitalis_area - anatomy_rh_parsorbitalis_area)',
#  'anatomy_lh_bankssts_area x (anatomy_lh_parsorbitalis_thickness - anatomy_rh_parsorbitalis_thickness)',
#  'anatomy_lh_bankssts_area x (anatomy_lh_postcentral_thickness - anatomy_rh_postcentral_thickness)',
#  'anatomy_lh_bankssts_area x (anatomy_lh_posteriorcingulate_area - anatomy_rh_posteriorcingulate_area)',
#  'anatomy_lh_bankssts_area x (anatomy_lh_posteriorcingulate_thickness - anatomy_rh_posteriorcingulate_thickness)',
#  'anatomy_lh_bankssts_area x (anatomy_lh_precentral_area - anatomy_rh_precentral_area)',
#  'anatomy_lh_bankssts_area x (anatomy_lh_precuneus_area - anatomy_rh_precuneus_area)',
#  'anatomy_lh_bankssts_area x (anatomy_lh_precuneus_thickness - anatomy_rh_precuneus_thickness)',
#  'anatomy_lh_bankssts_area x (anatomy_lh_superiorparietal_thickness - anatomy_rh_superiorparietal_thickness)',
#  'anatomy_lh_bankssts_area x (anatomy_lh_superiortemporal_area - anatomy_rh_superiortemporal_area)',
#  'anatomy_lh_bankssts_area x (anatomy_lh_superiortemporal_thickness - anatomy_rh_superiortemporal_thickness)',
#  'anatomy_lh_bankssts_area x (anatomy_lh_supramarginal_area - anatomy_rh_supramarginal_area)',
#  'anatomy_lh_bankssts_area x (anatomy_lh_supramarginal_thickness - anatomy_rh_supramarginal_thickness)',
#  'anatomy_lh_bankssts_area x (anatomy_lh_temporalpole_area - anatomy_rh_temporalpole_area)',
#  'anatomy_lh_bankssts_area x (anatomy_lh_temporalpole_thickness - anatomy_rh_temporalpole_thickness)',
#  'anatomy_lh_bankssts_area x (anatomy_lh_transversetemporal_area - anatomy_rh_transversetemporal_area)',
#  'anatomy_lh_bankssts_area x 1/(anatomy_lh_caudalanteriorcingulate_area)',
#  'anatomy_lh_bankssts_area x 1/(anatomy_lh_cuneus_area)',
#  'anatomy_lh_bankssts_area x 1/(anatomy_lh_entorhinal_area)',
#  'anatomy_lh_bankssts_area x 1/(anatomy_lh_isthmuscingulate_area)',
#  'anatomy_lh_bankssts_area x 1/(anatomy_lh_lateraloccipital_area)',
#  'anatomy_lh_bankssts_area x 1/(anatomy_lh_lingual_area)',
#  'anatomy_lh_bankssts_area x 1/(anatomy_lh_middletemporal_area)',
#  'anatomy_lh_bankssts_area x 1/(anatomy_lh_parahippocampal_area)',
#  'anatomy_lh_bankssts_area x 1/(anatomy_lh_paracentral_area)',
#  'anatomy_lh_bankssts_area x 1/(anatomy_lh_parsorbitalis_area)',
#  'anatomy_lh_bankssts_area x 1/(anatomy_lh_posteriorcingulate_area)',
#  'anatomy_lh_bankssts_area x 1/(anatomy_lh_precentral_area)',
#  'anatomy_lh_bankssts_area x 1/(anatomy_lh_rostralanteriorcingulate_area)',
#  'anatomy_lh_bankssts_area x 1/(anatomy_lh_superiorparietal_area)',
#  'anatomy_lh_bankssts_area x 1/(anatomy_lh_supramarginal_area)',
#  'anatomy_lh_bankssts_area x 1/(anatomy_lh_temporalpole_area)',
#  'anatomy_lh_bankssts_area x 1/(anatomy_lh_transversetemporal_area)',
#  'anatomy_lh_bankssts_area x 1/(anatomy_rh_bankssts_area)',
#  'anatomy_lh_bankssts_area x 1/(anatomy_rh_caudalmiddlefrontal_area)',
#  'anatomy_lh_bankssts_area x 1/(anatomy_rh_cuneus_area)',
#  'anatomy_lh_bankssts_area x 1/(anatomy_rh_entorhinal_area)',
#  'anatomy_lh_bankssts_area x 1/(anatomy_rh_inferiortemporal_area)',
#  'anatomy_lh_bankssts_area x 1/(anatomy_rh_isthmuscingulate_area)',
#  'anatomy_lh_bankssts_area x 1/(anatomy_rh_lateraloccipital_area)',
#  'anatomy_lh_bankssts_area x 1/(anatomy_rh_lingual_area)',
#  'anatomy_lh_bankssts_area x 1/(anatomy_rh_parahippocampal_area)',
#  'anatomy_lh_bankssts_area x 1/(anatomy_rh_parsorbitalis_area)',
#  'anatomy_lh_bankssts_area x 1/(anatomy_rh_parstriangularis_area)',
#  'anatomy_lh_bankssts_area x 1/(anatomy_rh_precuneus_area)',
#  'anatomy_lh_bankssts_area x 1/(anatomy_rh_superiorparietal_area)',
#  'anatomy_lh_bankssts_area x 1/(anatomy_rh_frontalpole_area)',
#  'anatomy_lh_bankssts_area x 1/(anatomy_rh_temporalpole_area)',
#  'anatomy_lh_bankssts_area x 1/(anatomy_lh_fusiform_thickness)',
#  'anatomy_lh_bankssts_area x 1/(anatomy_lh_isthmuscingulate_thickness)',
#  'anatomy_lh_bankssts_area x 1/(anatomy_lh_parsopercularis_thickness)',
#  'anatomy_lh_bankssts_area x 1/(anatomy_lh_parsorbitalis_thickness)',
#  'anatomy_lh_bankssts_area x 1/(anatomy_lh_superiortemporal_thickness)',
#  'anatomy_lh_bankssts_area x 1/(anatomy_lh_temporalpole_thickness)',
#  'anatomy_lh_bankssts_area x 1/(anatomy_rh_cuneus_thickness)',
#  'anatomy_lh_bankssts_area x 1/(anatomy_rh_fusiform_thickness)',
#  'anatomy_lh_bankssts_area x 1/(anatomy_rh_superiortemporal_thickness)',
#  'anatomy_lh_bankssts_area x 1/(anatomy_rh_temporalpole_thickness)',
#  'anatomy_lh_bankssts_area x 1/(anatomy_rh_transversetemporal_thickness)',
#  'anatomy_lh_bankssts_area x 1/(anatomy_Left-Lateral-Ventricle)',
#  'anatomy_lh_bankssts_area x 1/(anatomy_Left-Inf-Lat-Vent)',
#  'anatomy_lh_bankssts_area x 1/(anatomy_Left-Cerebellum-Cortex)',
#  'anatomy_lh_bankssts_area x 1/(anatomy_Left-Thalamus-Proper)',
#  'anatomy_lh_bankssts_area x 1/(anatomy_Left-Putamen)',
#  'anatomy_lh_bankssts_area x 1/(anatomy_Left-Pallidum)',
#  'anatomy_lh_bankssts_area x 1/(anatomy_3rd-Ventricle)',
#  'anatomy_lh_bankssts_area x 1/(anatomy_Left-Hippocampus)',
#  'anatomy_lh_bankssts_area x 1/(anatomy_CSF)',
#  'anatomy_lh_bankssts_area x 1/(anatomy_Left-VentralDC)',
#  'anatomy_lh_bankssts_area x 1/(anatomy_Right-Lateral-Ventricle)',
#  'anatomy_lh_bankssts_area x 1/(anatomy_Right-Inf-Lat-Vent)',
#  'anatomy_lh_bankssts_area x 1/(anatomy_Right-Pallidum)',
#  'anatomy_lh_bankssts_area x 1/(anatomy_Right-Hippocampus)',
#  'anatomy_lh_bankssts_area x 1/(anatomy_Right-Amygdala)',
#  'anatomy_lh_bankssts_area x 1/(anatomy_Right-vessel)',
#  'anatomy_lh_bankssts_area x 1/(anatomy_WM-hypointensities)',
#  'anatomy_lh_bankssts_area x 1/(anatomy_Optic-Chiasm)',
#  'anatomy_lh_bankssts_area x 1/(anatomy_CC_Posterior)',
#  'anatomy_lh_bankssts_area x 1/(anatomy_CC_Central)',
#  'anatomy_lh_bankssts_area x 1/(anatomy_CC_Mid_Anterior)',
#  'anatomy_lh_bankssts_area x 1/(anatomy_BrainSegVol)',
#  'anatomy_lh_bankssts_area x 1/(anatomy_MaskVol)',
#  'anatomy_lh_bankssts_area x 1/(anatomy_MaskVol-to-eTIV)',
#  'anatomy_lh_bankssts_area x 1/(anatomy_lhSurfaceHoles)',
#  'anatomy_lh_bankssts_area x 1/(anatomy_BrainSegVolNotVent)',
#  'anatomy_lh_bankssts_area x 1/((anatomy_Left-Caudate - anatomy_Right-Caudate))',
#  'anatomy_lh_bankssts_area x 1/((anatomy_Left-Cerebellum-Cortex - anatomy_Right-Cerebellum-Cortex))',
#  'anatomy_lh_bankssts_area x 1/((anatomy_Left-Putamen - anatomy_Right-Putamen))',
#  'anatomy_lh_bankssts_area x 1/((anatomy_Left-VentralDC - anatomy_Right-VentralDC))',
#  'anatomy_lh_bankssts_area x 1/((anatomy_lh_MeanThickness_thickness - anatomy_rh_MeanThickness_thickness))',
#  'anatomy_lh_bankssts_area x 1/((anatomy_lh_cuneus_thickness - anatomy_rh_cuneus_thickness))',
#  'anatomy_lh_bankssts_area x 1/((anatomy_lh_entorhinal_area - anatomy_rh_entorhinal_area))',
#  'anatomy_lh_bankssts_area x 1/((anatomy_lh_inferiorparietal_area - anatomy_rh_inferiorparietal_area))',
#  'anatomy_lh_bankssts_area x 1/((anatomy_lh_inferiortemporal_area - anatomy_rh_inferiortemporal_area))',
#  'anatomy_lh_bankssts_area x 1/((anatomy_lh_insula_thickness - anatomy_rh_insula_thickness))',
#  'anatomy_lh_bankssts_area x 1/((anatomy_lh_lingual_area - anatomy_rh_lingual_area))',
#  'anatomy_lh_bankssts_area x 1/((anatomy_lh_medialorbitofrontal_area - anatomy_rh_medialorbitofrontal_area))',
#  'anatomy_lh_bankssts_area x 1/((anatomy_lh_parsopercularis_thickness - anatomy_rh_parsopercularis_thickness))',
#  'anatomy_lh_bankssts_area x 1/((anatomy_lh_parsorbitalis_thickness - anatomy_rh_parsorbitalis_thickness))',
#  'anatomy_lh_bankssts_area x 1/((anatomy_lh_pericalcarine_thickness - anatomy_rh_pericalcarine_thickness))',
#  'anatomy_lh_bankssts_area x 1/((anatomy_lh_postcentral_area - anatomy_rh_postcentral_area))',
#  'anatomy_lh_bankssts_area x 1/((anatomy_lh_posteriorcingulate_area - anatomy_rh_posteriorcingulate_area))',
#  'anatomy_lh_bankssts_area x 1/((anatomy_lh_precentral_area - anatomy_rh_precentral_area))',
#  'anatomy_lh_bankssts_area x 1/((anatomy_lh_superiorfrontal_area - anatomy_rh_superiorfrontal_area))',
#  'anatomy_lh_bankssts_area x 1/((anatomy_lh_superiortemporal_area - anatomy_rh_superiortemporal_area))',
#  'anatomy_lh_bankssts_area x 1/((anatomy_lh_superiortemporal_thickness - anatomy_rh_superiortemporal_thickness))',
#  'anatomy_lh_bankssts_area x 1/((anatomy_lh_temporalpole_area - anatomy_rh_temporalpole_area))',
#  'anatomy_lh_bankssts_area x 1/((anatomy_lh_transversetemporal_area - anatomy_rh_transversetemporal_area))',
#  'anatomy_lh_bankssts_area x 1/((anatomy_SubCortGrayVol - anatomy_BrainSegVol))',
#  'anatomy_lh_bankssts_area x 1/((anatomy_TotalGrayVol - anatomy_CortexVol))',
#  'anatomy_lh_bankssts_area x 1/(participants_age)',
#  'anatomy_lh_caudalanteriorcingulate_area x anatomy_lh_entorhinal_area',
#  'anatomy_lh_caudalanteriorcingulate_area x anatomy_lh_inferiorparietal_area',
#  'anatomy_lh_caudalanteriorcingulate_area x anatomy_lh_lateralorbitofrontal_area',
#  'anatomy_lh_caudalanteriorcingulate_area x anatomy_lh_parahippocampal_area',
#  'anatomy_lh_caudalanteriorcingulate_area x anatomy_lh_paracentral_area',
#  'anatomy_lh_caudalanteriorcingulate_area x anatomy_lh_parsorbitalis_area',
#  'anatomy_lh_caudalanteriorcingulate_area x anatomy_lh_posteriorcingulate_area',
#  'anatomy_lh_caudalanteriorcingulate_area x anatomy_lh_precentral_area',
#  'anatomy_lh_caudalanteriorcingulate_area x anatomy_lh_precuneus_area',
#  'anatomy_lh_caudalanteriorcingulate_area x anatomy_lh_rostralanteriorcingulate_area',
#  'anatomy_lh_caudalanteriorcingulate_area x anatomy_lh_rostralmiddlefrontal_area',
#  'anatomy_lh_caudalanteriorcingulate_area x anatomy_lh_superiorfrontal_area',
#  'anatomy_lh_caudalanteriorcingulate_area x anatomy_lh_superiortemporal_area',
#  'anatomy_lh_caudalanteriorcingulate_area x anatomy_lh_frontalpole_area',
#  'anatomy_lh_caudalanteriorcingulate_area x anatomy_lh_temporalpole_area',
#  'anatomy_lh_caudalanteriorcingulate_area x anatomy_lh_transversetemporal_area',
#  'anatomy_lh_caudalanteriorcingulate_area x anatomy_lh_insula_area',
#  'anatomy_lh_caudalanteriorcingulate_area x anatomy_rh_bankssts_area',
#  'anatomy_lh_caudalanteriorcingulate_area x anatomy_rh_caudalanteriorcingulate_area',
#  'anatomy_lh_caudalanteriorcingulate_area x anatomy_rh_caudalmiddlefrontal_area',
#  'anatomy_lh_caudalanteriorcingulate_area x anatomy_rh_inferiorparietal_area',
#  'anatomy_lh_caudalanteriorcingulate_area x anatomy_rh_lateralorbitofrontal_area',
#  'anatomy_lh_caudalanteriorcingulate_area x anatomy_rh_lingual_area',
#  'anatomy_lh_caudalanteriorcingulate_area x anatomy_rh_parahippocampal_area',
#  'anatomy_lh_caudalanteriorcingulate_area x anatomy_rh_paracentral_area',
#  'anatomy_lh_caudalanteriorcingulate_area x anatomy_rh_parsopercularis_area',
#  'anatomy_lh_caudalanteriorcingulate_area x anatomy_rh_parsorbitalis_area',
#  'anatomy_lh_caudalanteriorcingulate_area x anatomy_rh_posteriorcingulate_area',
#  'anatomy_lh_caudalanteriorcingulate_area x anatomy_rh_precuneus_area',
#  'anatomy_lh_caudalanteriorcingulate_area x anatomy_rh_rostralanteriorcingulate_area',
#  'anatomy_lh_caudalanteriorcingulate_area x anatomy_rh_rostralmiddlefrontal_area',
#  'anatomy_lh_caudalanteriorcingulate_area x anatomy_rh_superiorfrontal_area',
#  'anatomy_lh_caudalanteriorcingulate_area x anatomy_rh_superiortemporal_area',
#  'anatomy_lh_caudalanteriorcingulate_area x anatomy_rh_transversetemporal_area',
#  'anatomy_lh_caudalanteriorcingulate_area x anatomy_lh_lateralorbitofrontal_thickness',
#  'anatomy_lh_caudalanteriorcingulate_area x anatomy_lh_parahippocampal_thickness',
#  'anatomy_lh_caudalanteriorcingulate_area x anatomy_lh_postcentral_thickness',
#  'anatomy_lh_caudalanteriorcingulate_area x anatomy_lh_temporalpole_thickness',
#  'anatomy_lh_caudalanteriorcingulate_area x anatomy_lh_transversetemporal_thickness',
#  'anatomy_lh_caudalanteriorcingulate_area x anatomy_rh_medialorbitofrontal_thickness',
#  'anatomy_lh_caudalanteriorcingulate_area x anatomy_rh_middletemporal_thickness',
#  'anatomy_lh_caudalanteriorcingulate_area x anatomy_rh_parstriangularis_thickness',
#  'anatomy_lh_caudalanteriorcingulate_area x anatomy_rh_postcentral_thickness',
#  'anatomy_lh_caudalanteriorcingulate_area x anatomy_rh_temporalpole_thickness',
#  'anatomy_lh_caudalanteriorcingulate_area x anatomy_Left-Lateral-Ventricle',
#  'anatomy_lh_caudalanteriorcingulate_area x anatomy_Left-Cerebellum-White-Matter',
#  'anatomy_lh_caudalanteriorcingulate_area x anatomy_Left-Cerebellum-Cortex',
#  'anatomy_lh_caudalanteriorcingulate_area x anatomy_Left-Putamen',
#  'anatomy_lh_caudalanteriorcingulate_area x anatomy_Left-Pallidum',
#  'anatomy_lh_caudalanteriorcingulate_area x anatomy_3rd-Ventricle',
#  'anatomy_lh_caudalanteriorcingulate_area x anatomy_4th-Ventricle',
#  'anatomy_lh_caudalanteriorcingulate_area x anatomy_Left-Hippocampus',
#  'anatomy_lh_caudalanteriorcingulate_area x anatomy_Left-Amygdala',
#  'anatomy_lh_caudalanteriorcingulate_area x anatomy_Left-Accumbens-area',
#  'anatomy_lh_caudalanteriorcingulate_area x anatomy_Left-VentralDC',
#  'anatomy_lh_caudalanteriorcingulate_area x anatomy_Right-Inf-Lat-Vent',
#  'anatomy_lh_caudalanteriorcingulate_area x anatomy_Right-Cerebellum-White-Matter',
#  'anatomy_lh_caudalanteriorcingulate_area x anatomy_Right-Pallidum',
#  'anatomy_lh_caudalanteriorcingulate_area x anatomy_Right-Hippocampus',
#  'anatomy_lh_caudalanteriorcingulate_area x anatomy_Right-Amygdala',
#  'anatomy_lh_caudalanteriorcingulate_area x anatomy_Right-Accumbens-area',
#  'anatomy_lh_caudalanteriorcingulate_area x anatomy_Right-vessel',
#  'anatomy_lh_caudalanteriorcingulate_area x anatomy_Optic-Chiasm',
#  'anatomy_lh_caudalanteriorcingulate_area x anatomy_CC_Mid_Posterior',
#  'anatomy_lh_caudalanteriorcingulate_area x anatomy_CC_Mid_Anterior',
#  'anatomy_lh_caudalanteriorcingulate_area x anatomy_CC_Anterior',
#  'anatomy_lh_caudalanteriorcingulate_area x anatomy_lhCerebralWhiteMatterVol',
#  'anatomy_lh_caudalanteriorcingulate_area x anatomy_CerebralWhiteMatterVol',
#  'anatomy_lh_caudalanteriorcingulate_area x anatomy_MaskVol',
#  'anatomy_lh_caudalanteriorcingulate_area x anatomy_MaskVol-to-eTIV',
#  'anatomy_lh_caudalanteriorcingulate_area x (anatomy_Left-Accumbens-area - anatomy_Right-Accumbens-area)',
#  'anatomy_lh_caudalanteriorcingulate_area x (anatomy_Left-Amygdala - anatomy_Right-Amygdala)',
#  'anatomy_lh_caudalanteriorcingulate_area x (anatomy_Left-Hippocampus - anatomy_Right-Hippocampus)',
#  'anatomy_lh_caudalanteriorcingulate_area x (anatomy_Left-Inf-Lat-Vent - anatomy_Right-Inf-Lat-Vent)',
#  'anatomy_lh_caudalanteriorcingulate_area x (anatomy_Left-Lateral-Ventricle - anatomy_Right-Lateral-Ventricle)',
#  'anatomy_lh_caudalanteriorcingulate_area x (anatomy_Left-Putamen - anatomy_Right-Putamen)',
#  'anatomy_lh_caudalanteriorcingulate_area x (anatomy_Left-Thalamus-Proper - anatomy_Right-Thalamus-Proper)',
#  'anatomy_lh_caudalanteriorcingulate_area x (anatomy_Left-VentralDC - anatomy_Right-VentralDC)',
#  'anatomy_lh_caudalanteriorcingulate_area x (anatomy_Left-choroid-plexus - anatomy_Right-choroid-plexus)',
#  'anatomy_lh_caudalanteriorcingulate_area x (anatomy_Left-vessel - anatomy_Right-vessel)',
#  'anatomy_lh_caudalanteriorcingulate_area x (anatomy_lhCerebralWhiteMatterVol - anatomy_rhCerebralWhiteMatterVol)',
#  'anatomy_lh_caudalanteriorcingulate_area x (anatomy_lh_MeanThickness_thickness - anatomy_rh_MeanThickness_thickness)',
#  'anatomy_lh_caudalanteriorcingulate_area x (anatomy_lh_caudalanteriorcingulate_area - anatomy_rh_caudalanteriorcingulate_area)',
#  'anatomy_lh_caudalanteriorcingulate_area x (anatomy_lh_caudalmiddlefrontal_area - anatomy_rh_caudalmiddlefrontal_area)',
#  'anatomy_lh_caudalanteriorcingulate_area x (anatomy_lh_cuneus_thickness - anatomy_rh_cuneus_thickness)',
#  'anatomy_lh_caudalanteriorcingulate_area x (anatomy_lh_entorhinal_area - anatomy_rh_entorhinal_area)',
#  'anatomy_lh_caudalanteriorcingulate_area x (anatomy_lh_frontalpole_area - anatomy_rh_frontalpole_area)',
#  'anatomy_lh_caudalanteriorcingulate_area x (anatomy_lh_fusiform_area - anatomy_rh_fusiform_area)',
#  'anatomy_lh_caudalanteriorcingulate_area x (anatomy_lh_fusiform_thickness - anatomy_rh_fusiform_thickness)',
#  'anatomy_lh_caudalanteriorcingulate_area x (anatomy_lh_inferiorparietal_thickness - anatomy_rh_inferiorparietal_thickness)',
#  'anatomy_lh_caudalanteriorcingulate_area x (anatomy_lh_inferiortemporal_area - anatomy_rh_inferiortemporal_area)',
#  'anatomy_lh_caudalanteriorcingulate_area x (anatomy_lh_inferiortemporal_thickness - anatomy_rh_inferiortemporal_thickness)',
#  'anatomy_lh_caudalanteriorcingulate_area x (anatomy_lh_insula_area - anatomy_rh_insula_area)',
#  'anatomy_lh_caudalanteriorcingulate_area x (anatomy_lh_insula_thickness - anatomy_rh_insula_thickness)',
#  'anatomy_lh_caudalanteriorcingulate_area x (anatomy_lh_isthmuscingulate_area - anatomy_rh_isthmuscingulate_area)',
#  'anatomy_lh_caudalanteriorcingulate_area x (anatomy_lh_isthmuscingulate_thickness - anatomy_rh_isthmuscingulate_thickness)',
#  'anatomy_lh_caudalanteriorcingulate_area x (anatomy_lh_lateralorbitofrontal_thickness - anatomy_rh_lateralorbitofrontal_thickness)',
#  'anatomy_lh_caudalanteriorcingulate_area x (anatomy_lh_medialorbitofrontal_thickness - anatomy_rh_medialorbitofrontal_thickness)',
#  'anatomy_lh_caudalanteriorcingulate_area x (anatomy_lh_middletemporal_thickness - anatomy_rh_middletemporal_thickness)',
#  'anatomy_lh_caudalanteriorcingulate_area x (anatomy_lh_paracentral_area - anatomy_rh_paracentral_area)',
#  'anatomy_lh_caudalanteriorcingulate_area x (anatomy_lh_paracentral_thickness - anatomy_rh_paracentral_thickness)',
#  'anatomy_lh_caudalanteriorcingulate_area x (anatomy_lh_parahippocampal_thickness - anatomy_rh_parahippocampal_thickness)',
#  'anatomy_lh_caudalanteriorcingulate_area x (anatomy_lh_parsopercularis_area - anatomy_rh_parsopercularis_area)',
#  'anatomy_lh_caudalanteriorcingulate_area x (anatomy_lh_posteriorcingulate_thickness - anatomy_rh_posteriorcingulate_thickness)',
#  'anatomy_lh_caudalanteriorcingulate_area x (anatomy_lh_precentral_area - anatomy_rh_precentral_area)',
#  'anatomy_lh_caudalanteriorcingulate_area x (anatomy_lh_precentral_thickness - anatomy_rh_precentral_thickness)',
#  'anatomy_lh_caudalanteriorcingulate_area x (anatomy_lh_precuneus_area - anatomy_rh_precuneus_area)',
#  'anatomy_lh_caudalanteriorcingulate_area x (anatomy_lh_rostralanteriorcingulate_area - anatomy_rh_rostralanteriorcingulate_area)',
#  'anatomy_lh_caudalanteriorcingulate_area x (anatomy_lh_rostralmiddlefrontal_thickness - anatomy_rh_rostralmiddlefrontal_thickness)',
#  'anatomy_lh_caudalanteriorcingulate_area x (anatomy_lh_superiorfrontal_area - anatomy_rh_superiorfrontal_area)',
#  'anatomy_lh_caudalanteriorcingulate_area x (anatomy_lh_superiorfrontal_thickness - anatomy_rh_superiorfrontal_thickness)',
#  'anatomy_lh_caudalanteriorcingulate_area x (anatomy_lh_superiorparietal_area - anatomy_rh_superiorparietal_area)',
#  'anatomy_lh_caudalanteriorcingulate_area x (anatomy_lh_superiortemporal_thickness - anatomy_rh_superiortemporal_thickness)',
#  'anatomy_lh_caudalanteriorcingulate_area x (anatomy_lh_temporalpole_area - anatomy_rh_temporalpole_area)',
#  'anatomy_lh_caudalanteriorcingulate_area x (anatomy_lh_temporalpole_thickness - anatomy_rh_temporalpole_thickness)',
#  'anatomy_lh_caudalanteriorcingulate_area x (anatomy_lh_transversetemporal_area - anatomy_rh_transversetemporal_area)',
#  'anatomy_lh_caudalanteriorcingulate_area x (anatomy_lh_transversetemporal_thickness - anatomy_rh_transversetemporal_thickness)',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/(anatomy_lh_bankssts_area)',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/(anatomy_lh_cuneus_area)',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/(anatomy_lh_entorhinal_area)',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/(anatomy_lh_inferiorparietal_area)',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/(anatomy_lh_isthmuscingulate_area)',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/(anatomy_lh_lateralorbitofrontal_area)',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/(anatomy_lh_lingual_area)',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/(anatomy_lh_medialorbitofrontal_area)',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/(anatomy_lh_parahippocampal_area)',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/(anatomy_lh_parsopercularis_area)',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/(anatomy_lh_parsorbitalis_area)',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/(anatomy_lh_parstriangularis_area)',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/(anatomy_lh_posteriorcingulate_area)',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/(anatomy_lh_precuneus_area)',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/(anatomy_lh_rostralanteriorcingulate_area)',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/(anatomy_lh_rostralmiddlefrontal_area)',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/(anatomy_lh_superiorfrontal_area)',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/(anatomy_lh_superiorparietal_area)',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/(anatomy_lh_superiortemporal_area)',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/(anatomy_lh_frontalpole_area)',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/(anatomy_lh_transversetemporal_area)',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/(anatomy_lh_insula_area)',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/(anatomy_rh_caudalanteriorcingulate_area)',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/(anatomy_rh_caudalmiddlefrontal_area)',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/(anatomy_rh_entorhinal_area)',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/(anatomy_rh_isthmuscingulate_area)',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/(anatomy_rh_lateralorbitofrontal_area)',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/(anatomy_rh_lingual_area)',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/(anatomy_rh_medialorbitofrontal_area)',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/(anatomy_rh_parahippocampal_area)',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/(anatomy_rh_paracentral_area)',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/(anatomy_rh_parsorbitalis_area)',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/(anatomy_rh_parstriangularis_area)',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/(anatomy_rh_posteriorcingulate_area)',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/(anatomy_rh_precuneus_area)',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/(anatomy_rh_rostralanteriorcingulate_area)',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/(anatomy_rh_superiorfrontal_area)',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/(anatomy_rh_superiorparietal_area)',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/(anatomy_rh_supramarginal_area)',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/(anatomy_lh_cuneus_thickness)',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/(anatomy_lh_isthmuscingulate_thickness)',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/(anatomy_lh_lateralorbitofrontal_thickness)',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/(anatomy_lh_parahippocampal_thickness)',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/(anatomy_lh_parstriangularis_thickness)',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/(anatomy_lh_postcentral_thickness)',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/(anatomy_lh_transversetemporal_thickness)',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/(anatomy_rh_bankssts_thickness)',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/(anatomy_rh_entorhinal_thickness)',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/(anatomy_rh_inferiortemporal_thickness)',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/(anatomy_rh_lateralorbitofrontal_thickness)',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/(anatomy_rh_medialorbitofrontal_thickness)',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/(anatomy_rh_middletemporal_thickness)',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/(anatomy_rh_parsopercularis_thickness)',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/(anatomy_rh_parsorbitalis_thickness)',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/(anatomy_rh_parstriangularis_thickness)',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/(anatomy_rh_temporalpole_thickness)',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/(anatomy_Left-Lateral-Ventricle)',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/(anatomy_Left-Cerebellum-White-Matter)',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/(anatomy_Left-Cerebellum-Cortex)',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/(anatomy_Left-Putamen)',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/(anatomy_Left-Pallidum)',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/(anatomy_3rd-Ventricle)',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/(anatomy_4th-Ventricle)',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/(anatomy_Brain-Stem)',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/(anatomy_Left-Hippocampus)',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/(anatomy_CSF)',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/(anatomy_Left-VentralDC)',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/(anatomy_Left-vessel)',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/(anatomy_Left-choroid-plexus)',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/(anatomy_Right-Inf-Lat-Vent)',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/(anatomy_Right-Cerebellum-White-Matter)',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/(anatomy_Right-Pallidum)',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/(anatomy_Right-Hippocampus)',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/(anatomy_Right-Amygdala)',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/(anatomy_Right-Accumbens-area)',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/(anatomy_CC_Mid_Posterior)',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/(anatomy_CC_Central)',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/(anatomy_BrainSegVol)',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/(anatomy_BrainSegVolNotVentSurf)',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/(anatomy_lhCerebralWhiteMatterVol)',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/(anatomy_CerebralWhiteMatterVol)',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/(anatomy_SupraTentorialVol)',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/(anatomy_SupraTentorialVolNotVent)',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/(anatomy_SurfaceHoles)',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/(anatomy_BrainSegVolNotVent)',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/((anatomy_Left-Pallidum - anatomy_Right-Pallidum))',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/((anatomy_Left-choroid-plexus - anatomy_Right-choroid-plexus))',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/((anatomy_lhSurfaceHoles - anatomy_rhSurfaceHoles))',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/((anatomy_lh_MeanThickness_thickness - anatomy_rh_MeanThickness_thickness))',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/((anatomy_lh_inferiorparietal_area - anatomy_rh_inferiorparietal_area))',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/((anatomy_lh_inferiorparietal_thickness - anatomy_rh_inferiorparietal_thickness))',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/((anatomy_lh_lateralorbitofrontal_thickness - anatomy_rh_lateralorbitofrontal_thickness))',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/((anatomy_lh_parahippocampal_area - anatomy_rh_parahippocampal_area))',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/((anatomy_lh_parsopercularis_thickness - anatomy_rh_parsopercularis_thickness))',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/((anatomy_lh_parstriangularis_area - anatomy_rh_parstriangularis_area))',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/((anatomy_lh_pericalcarine_thickness - anatomy_rh_pericalcarine_thickness))',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/((anatomy_lh_posteriorcingulate_area - anatomy_rh_posteriorcingulate_area))',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/((anatomy_lh_precentral_area - anatomy_rh_precentral_area))',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/((anatomy_lh_precuneus_thickness - anatomy_rh_precuneus_thickness))',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/((anatomy_lh_rostralmiddlefrontal_thickness - anatomy_rh_rostralmiddlefrontal_thickness))',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/((anatomy_lh_superiorfrontal_area - anatomy_rh_superiorfrontal_area))',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/((anatomy_lh_superiortemporal_area - anatomy_rh_superiortemporal_area))',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/((anatomy_lh_temporalpole_area - anatomy_rh_temporalpole_area))',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/((anatomy_lh_transversetemporal_area - anatomy_rh_transversetemporal_area))',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/((anatomy_SubCortGrayVol - anatomy_BrainSegVol))',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/((anatomy_TotalGrayVol - anatomy_CortexVol))',
#  'anatomy_lh_caudalanteriorcingulate_area x 1/(participants_age)',
#  'anatomy_lh_caudalmiddlefrontal_area x anatomy_lh_entorhinal_area',
#  'anatomy_lh_caudalmiddlefrontal_area x anatomy_lh_fusiform_area',
#  'anatomy_lh_caudalmiddlefrontal_area x anatomy_lh_lateraloccipital_area',
#  'anatomy_lh_caudalmiddlefrontal_area x anatomy_lh_middletemporal_area',
#  'anatomy_lh_caudalmiddlefrontal_area x anatomy_lh_parstriangularis_area',
#  'anatomy_lh_caudalmiddlefrontal_area x anatomy_lh_pericalcarine_area',
#  'anatomy_lh_caudalmiddlefrontal_area x anatomy_lh_postcentral_area',
#  'anatomy_lh_caudalmiddlefrontal_area x anatomy_lh_posteriorcingulate_area',
#  'anatomy_lh_caudalmiddlefrontal_area x anatomy_lh_rostralanteriorcingulate_area',
#  'anatomy_lh_caudalmiddlefrontal_area x anatomy_lh_superiorfrontal_area',
#  'anatomy_lh_caudalmiddlefrontal_area x anatomy_lh_frontalpole_area',
#  'anatomy_lh_caudalmiddlefrontal_area x anatomy_lh_transversetemporal_area',
#  'anatomy_lh_caudalmiddlefrontal_area x anatomy_rh_fusiform_area',
#  'anatomy_lh_caudalmiddlefrontal_area x anatomy_rh_isthmuscingulate_area',
#  'anatomy_lh_caudalmiddlefrontal_area x anatomy_rh_parsorbitalis_area',
#  'anatomy_lh_caudalmiddlefrontal_area x anatomy_rh_pericalcarine_area',
#  'anatomy_lh_caudalmiddlefrontal_area x anatomy_rh_posteriorcingulate_area',
#  'anatomy_lh_caudalmiddlefrontal_area x anatomy_rh_rostralmiddlefrontal_area',
#  'anatomy_lh_caudalmiddlefrontal_area x anatomy_rh_transversetemporal_area',
#  'anatomy_lh_caudalmiddlefrontal_area x anatomy_rh_insula_area',
#  'anatomy_lh_caudalmiddlefrontal_area x anatomy_lh_middletemporal_thickness',
#  'anatomy_lh_caudalmiddlefrontal_area x anatomy_lh_pericalcarine_thickness',
#  'anatomy_lh_caudalmiddlefrontal_area x anatomy_lh_transversetemporal_thickness',
#  'anatomy_lh_caudalmiddlefrontal_area x anatomy_rh_caudalanteriorcingulate_thickness',
#  'anatomy_lh_caudalmiddlefrontal_area x anatomy_rh_cuneus_thickness',
#  'anatomy_lh_caudalmiddlefrontal_area x anatomy_rh_pericalcarine_thickness',
#  'anatomy_lh_caudalmiddlefrontal_area x anatomy_rh_rostralanteriorcingulate_thickness',
#  'anatomy_lh_caudalmiddlefrontal_area x anatomy_rh_rostralmiddlefrontal_thickness',
#  'anatomy_lh_caudalmiddlefrontal_area x anatomy_rh_transversetemporal_thickness',
#  'anatomy_lh_caudalmiddlefrontal_area x anatomy_Left-Lateral-Ventricle',
#  'anatomy_lh_caudalmiddlefrontal_area x anatomy_Left-Inf-Lat-Vent',
#  'anatomy_lh_caudalmiddlefrontal_area x anatomy_Left-Cerebellum-Cortex',
#  'anatomy_lh_caudalmiddlefrontal_area x anatomy_4th-Ventricle',
#  'anatomy_lh_caudalmiddlefrontal_area x anatomy_Brain-Stem',
#  'anatomy_lh_caudalmiddlefrontal_area x anatomy_Left-vessel',
#  'anatomy_lh_caudalmiddlefrontal_area x anatomy_Left-choroid-plexus',
#  'anatomy_lh_caudalmiddlefrontal_area x anatomy_Right-Lateral-Ventricle',
#  'anatomy_lh_caudalmiddlefrontal_area x anatomy_Right-Inf-Lat-Vent',
#  'anatomy_lh_caudalmiddlefrontal_area x anatomy_Right-Cerebellum-White-Matter',
#  'anatomy_lh_caudalmiddlefrontal_area x anatomy_Right-choroid-plexus',
#  'anatomy_lh_caudalmiddlefrontal_area x anatomy_Optic-Chiasm',
#  'anatomy_lh_caudalmiddlefrontal_area x anatomy_CC_Posterior',
#  'anatomy_lh_caudalmiddlefrontal_area x anatomy_CC_Mid_Anterior',
#  'anatomy_lh_caudalmiddlefrontal_area x anatomy_BrainSegVol',
#  'anatomy_lh_caudalmiddlefrontal_area x anatomy_MaskVol',
#  'anatomy_lh_caudalmiddlefrontal_area x anatomy_MaskVol-to-eTIV',
#  'anatomy_lh_caudalmiddlefrontal_area x anatomy_eTIV',
#  'anatomy_lh_caudalmiddlefrontal_area x anatomy_BrainSegVolNotVent',
#  'anatomy_lh_caudalmiddlefrontal_area x (anatomy_Left-Amygdala - anatomy_Right-Amygdala)',
#  'anatomy_lh_caudalmiddlefrontal_area x (anatomy_Left-Caudate - anatomy_Right-Caudate)',
#  'anatomy_lh_caudalmiddlefrontal_area x (anatomy_Left-Cerebellum-White-Matter - anatomy_Right-Cerebellum-White-Matter)',
#  'anatomy_lh_caudalmiddlefrontal_area x (anatomy_Left-Hippocampus - anatomy_Right-Hippocampus)',
#  'anatomy_lh_caudalmiddlefrontal_area x (anatomy_Left-Thalamus-Proper - anatomy_Right-Thalamus-Proper)',
#  'anatomy_lh_caudalmiddlefrontal_area x (anatomy_Left-VentralDC - anatomy_Right-VentralDC)',
#  'anatomy_lh_caudalmiddlefrontal_area x (anatomy_Left-vessel - anatomy_Right-vessel)',
#  'anatomy_lh_caudalmiddlefrontal_area x (anatomy_lhCortexVol - anatomy_rhCortexVol)',
#  'anatomy_lh_caudalmiddlefrontal_area x (anatomy_lhSurfaceHoles - anatomy_rhSurfaceHoles)',
#  'anatomy_lh_caudalmiddlefrontal_area x (anatomy_lh_MeanThickness_thickness - anatomy_rh_MeanThickness_thickness)',
#  'anatomy_lh_caudalmiddlefrontal_area x (anatomy_lh_WhiteSurfArea_area - anatomy_rh_WhiteSurfArea_area)',
#  'anatomy_lh_caudalmiddlefrontal_area x (anatomy_lh_bankssts_area - anatomy_rh_bankssts_area)',
#  'anatomy_lh_caudalmiddlefrontal_area x (anatomy_lh_bankssts_thickness - anatomy_rh_bankssts_thickness)',
#  'anatomy_lh_caudalmiddlefrontal_area x (anatomy_lh_caudalanteriorcingulate_thickness - anatomy_rh_caudalanteriorcingulate_thickness)',
#  'anatomy_lh_caudalmiddlefrontal_area x (anatomy_lh_caudalmiddlefrontal_area - anatomy_rh_caudalmiddlefrontal_area)',
#  'anatomy_lh_caudalmiddlefrontal_area x (anatomy_lh_caudalmiddlefrontal_thickness - anatomy_rh_caudalmiddlefrontal_thickness)',
#  'anatomy_lh_caudalmiddlefrontal_area x (anatomy_lh_cuneus_area - anatomy_rh_cuneus_area)',
#  'anatomy_lh_caudalmiddlefrontal_area x (anatomy_lh_cuneus_thickness - anatomy_rh_cuneus_thickness)',
#  'anatomy_lh_caudalmiddlefrontal_area x (anatomy_lh_entorhinal_area - anatomy_rh_entorhinal_area)',
#  'anatomy_lh_caudalmiddlefrontal_area x (anatomy_lh_frontalpole_area - anatomy_rh_frontalpole_area)',
#  'anatomy_lh_caudalmiddlefrontal_area x (anatomy_lh_fusiform_area - anatomy_rh_fusiform_area)',
#  'anatomy_lh_caudalmiddlefrontal_area x (anatomy_lh_fusiform_thickness - anatomy_rh_fusiform_thickness)',
#  'anatomy_lh_caudalmiddlefrontal_area x (anatomy_lh_inferiorparietal_thickness - anatomy_rh_inferiorparietal_thickness)',
#  'anatomy_lh_caudalmiddlefrontal_area x (anatomy_lh_inferiortemporal_area - anatomy_rh_inferiortemporal_area)',
#  'anatomy_lh_caudalmiddlefrontal_area x (anatomy_lh_insula_area - anatomy_rh_insula_area)',
#  'anatomy_lh_caudalmiddlefrontal_area x (anatomy_lh_insula_thickness - anatomy_rh_insula_thickness)',
#  'anatomy_lh_caudalmiddlefrontal_area x (anatomy_lh_isthmuscingulate_area - anatomy_rh_isthmuscingulate_area)',
#  'anatomy_lh_caudalmiddlefrontal_area x (anatomy_lh_lateraloccipital_area - anatomy_rh_lateraloccipital_area)',
#  'anatomy_lh_caudalmiddlefrontal_area x (anatomy_lh_lateraloccipital_thickness - anatomy_rh_lateraloccipital_thickness)',
#  'anatomy_lh_caudalmiddlefrontal_area x (anatomy_lh_lingual_area - anatomy_rh_lingual_area)',
#  'anatomy_lh_caudalmiddlefrontal_area x (anatomy_lh_medialorbitofrontal_thickness - anatomy_rh_medialorbitofrontal_thickness)',
#  'anatomy_lh_caudalmiddlefrontal_area x (anatomy_lh_parsopercularis_area - anatomy_rh_parsopercularis_area)',
#  'anatomy_lh_caudalmiddlefrontal_area x (anatomy_lh_parsopercularis_thickness - anatomy_rh_parsopercularis_thickness)',
#  'anatomy_lh_caudalmiddlefrontal_area x (anatomy_lh_parsorbitalis_area - anatomy_rh_parsorbitalis_area)',
#  'anatomy_lh_caudalmiddlefrontal_area x (anatomy_lh_parstriangularis_area - anatomy_rh_parstriangularis_area)',
#  'anatomy_lh_caudalmiddlefrontal_area x (anatomy_lh_parstriangularis_thickness - anatomy_rh_parstriangularis_thickness)',
#  'anatomy_lh_caudalmiddlefrontal_area x (anatomy_lh_pericalcarine_thickness - anatomy_rh_pericalcarine_thickness)',
#  'anatomy_lh_caudalmiddlefrontal_area x (anatomy_lh_postcentral_area - anatomy_rh_postcentral_area)',
#  'anatomy_lh_caudalmiddlefrontal_area x (anatomy_lh_precentral_area - anatomy_rh_precentral_area)',
#  'anatomy_lh_caudalmiddlefrontal_area x (anatomy_lh_rostralanteriorcingulate_area - anatomy_rh_rostralanteriorcingulate_area)',
#  'anatomy_lh_caudalmiddlefrontal_area x (anatomy_lh_rostralmiddlefrontal_area - anatomy_rh_rostralmiddlefrontal_area)',
# ...
#  'anatomy_lh_cuneus_area x (anatomy_Left-Lateral-Ventricle - anatomy_Right-Lateral-Ventricle)',
#  'anatomy_lh_cuneus_area x (anatomy_Left-Pallidum - anatomy_Right-Pallidum)',
#  'anatomy_lh_cuneus_area x (anatomy_Left-Putamen - anatomy_Right-Putamen)',
#  'anatomy_lh_cuneus_area x (anatomy_Left-Thalamus-Proper - anatomy_Right-Thalamus-Proper)',
#  'anatomy_lh_cuneus_area x (anatomy_Left-VentralDC - anatomy_Right-VentralDC)',
#  'anatomy_lh_cuneus_area x (anatomy_Left-choroid-plexus - anatomy_Right-choroid-plexus)',
#  'anatomy_lh_cuneus_area x (anatomy_lhSurfaceHoles - anatomy_rhSurfaceHoles)',
#  'anatomy_lh_cuneus_area x (anatomy_lh_MeanThickness_thickness - anatomy_rh_MeanThickness_thickness)',
#  'anatomy_lh_cuneus_area x (anatomy_lh_WhiteSurfArea_area - anatomy_rh_WhiteSurfArea_area)',
#  'anatomy_lh_cuneus_area x (anatomy_lh_caudalanteriorcingulate_thickness - anatomy_rh_caudalanteriorcingulate_thickness)',
#  'anatomy_lh_cuneus_area x (anatomy_lh_caudalmiddlefrontal_area - anatomy_rh_caudalmiddlefrontal_area)',
#  'anatomy_lh_cuneus_area x (anatomy_lh_caudalmiddlefrontal_thickness - anatomy_rh_caudalmiddlefrontal_thickness)',
#  'anatomy_lh_cuneus_area x (anatomy_lh_entorhinal_thickness - anatomy_rh_entorhinal_thickness)',
#  'anatomy_lh_cuneus_area x (anatomy_lh_frontalpole_area - anatomy_rh_frontalpole_area)',
#  'anatomy_lh_cuneus_area x (anatomy_lh_fusiform_area - anatomy_rh_fusiform_area)',
#  'anatomy_lh_cuneus_area x (anatomy_lh_inferiorparietal_area - anatomy_rh_inferiorparietal_area)',
#  'anatomy_lh_cuneus_area x (anatomy_lh_inferiorparietal_thickness - anatomy_rh_inferiorparietal_thickness)',
#  'anatomy_lh_cuneus_area x (anatomy_lh_insula_thickness - anatomy_rh_insula_thickness)',
#  'anatomy_lh_cuneus_area x (anatomy_lh_isthmuscingulate_area - anatomy_rh_isthmuscingulate_area)',
#  'anatomy_lh_cuneus_area x (anatomy_lh_lateraloccipital_area - anatomy_rh_lateraloccipital_area)',
#  'anatomy_lh_cuneus_area x (anatomy_lh_lateraloccipital_thickness - anatomy_rh_lateraloccipital_thickness)',
#  'anatomy_lh_cuneus_area x (anatomy_lh_lingual_thickness - anatomy_rh_lingual_thickness)',
#  'anatomy_lh_cuneus_area x (anatomy_lh_medialorbitofrontal_area - anatomy_rh_medialorbitofrontal_area)',
#  'anatomy_lh_cuneus_area x (anatomy_lh_medialorbitofrontal_thickness - anatomy_rh_medialorbitofrontal_thickness)',
#  'anatomy_lh_cuneus_area x (anatomy_lh_middletemporal_area - anatomy_rh_middletemporal_area)',
#  'anatomy_lh_cuneus_area x (anatomy_lh_paracentral_thickness - anatomy_rh_paracentral_thickness)',
#  'anatomy_lh_cuneus_area x (anatomy_lh_parsopercularis_thickness - anatomy_rh_parsopercularis_thickness)',
#  'anatomy_lh_cuneus_area x (anatomy_lh_parsorbitalis_thickness - anatomy_rh_parsorbitalis_thickness)',
#  'anatomy_lh_cuneus_area x (anatomy_lh_parstriangularis_area - anatomy_rh_parstriangularis_area)',
#  'anatomy_lh_cuneus_area x (anatomy_lh_parstriangularis_thickness - anatomy_rh_parstriangularis_thickness)',
#  'anatomy_lh_cuneus_area x (anatomy_lh_pericalcarine_area - anatomy_rh_pericalcarine_area)',
#  'anatomy_lh_cuneus_area x (anatomy_lh_pericalcarine_thickness - anatomy_rh_pericalcarine_thickness)',
#  'anatomy_lh_cuneus_area x (anatomy_lh_postcentral_area - anatomy_rh_postcentral_area)',
#  'anatomy_lh_cuneus_area x (anatomy_lh_posteriorcingulate_area - anatomy_rh_posteriorcingulate_area)',
#  'anatomy_lh_cuneus_area x (anatomy_lh_posteriorcingulate_thickness - anatomy_rh_posteriorcingulate_thickness)',
#  'anatomy_lh_cuneus_area x (anatomy_lh_precentral_area - anatomy_rh_precentral_area)',
#  'anatomy_lh_cuneus_area x (anatomy_lh_precentral_thickness - anatomy_rh_precentral_thickness)',
#  'anatomy_lh_cuneus_area x (anatomy_lh_precuneus_area - anatomy_rh_precuneus_area)',
#  'anatomy_lh_cuneus_area x (anatomy_lh_precuneus_thickness - anatomy_rh_precuneus_thickness)',
#  'anatomy_lh_cuneus_area x (anatomy_lh_rostralanteriorcingulate_area - anatomy_rh_rostralanteriorcingulate_area)',
#  'anatomy_lh_cuneus_area x (anatomy_lh_rostralanteriorcingulate_thickness - anatomy_rh_rostralanteriorcingulate_thickness)',
#  'anatomy_lh_cuneus_area x (anatomy_lh_rostralmiddlefrontal_area - anatomy_rh_rostralmiddlefrontal_area)',
#  'anatomy_lh_cuneus_area x (anatomy_lh_rostralmiddlefrontal_thickness - anatomy_rh_rostralmiddlefrontal_thickness)',
#  'anatomy_lh_cuneus_area x (anatomy_lh_superiorparietal_thickness - anatomy_rh_superiorparietal_thickness)',
#  'anatomy_lh_cuneus_area x (anatomy_lh_supramarginal_area - anatomy_rh_supramarginal_area)',
#  'anatomy_lh_cuneus_area x (anatomy_lh_supramarginal_thickness - anatomy_rh_supramarginal_thickness)',
#  'anatomy_lh_cuneus_area x (anatomy_lh_temporalpole_thickness - anatomy_rh_temporalpole_thickness)',
#  'anatomy_lh_cuneus_area x (anatomy_lh_transversetemporal_area - anatomy_rh_transversetemporal_area)',
#  'anatomy_lh_cuneus_area x 1/(anatomy_lh_bankssts_area)',
#  'anatomy_lh_cuneus_area x 1/(anatomy_lh_caudalmiddlefrontal_area)',
#  'anatomy_lh_cuneus_area x 1/(anatomy_lh_entorhinal_area)',
#  'anatomy_lh_cuneus_area x 1/(anatomy_lh_fusiform_area)',
#  'anatomy_lh_cuneus_area x 1/(anatomy_lh_inferiorparietal_area)',
#  'anatomy_lh_cuneus_area x 1/(anatomy_lh_inferiortemporal_area)',
#  'anatomy_lh_cuneus_area x 1/(anatomy_lh_lateralorbitofrontal_area)',
#  'anatomy_lh_cuneus_area x 1/(anatomy_lh_lingual_area)',
#  'anatomy_lh_cuneus_area x 1/(anatomy_lh_medialorbitofrontal_area)',
#  'anatomy_lh_cuneus_area x 1/(anatomy_lh_middletemporal_area)',
#  'anatomy_lh_cuneus_area x 1/(anatomy_lh_parahippocampal_area)',
#  'anatomy_lh_cuneus_area x 1/(anatomy_lh_parsorbitalis_area)',
#  'anatomy_lh_cuneus_area x 1/(anatomy_lh_parstriangularis_area)',
#  'anatomy_lh_cuneus_area x 1/(anatomy_lh_pericalcarine_area)',
#  'anatomy_lh_cuneus_area x 1/(anatomy_lh_posteriorcingulate_area)',
#  'anatomy_lh_cuneus_area x 1/(anatomy_lh_rostralanteriorcingulate_area)',
#  'anatomy_lh_cuneus_area x 1/(anatomy_lh_rostralmiddlefrontal_area)',
#  'anatomy_lh_cuneus_area x 1/(anatomy_lh_superiorfrontal_area)',
#  'anatomy_lh_cuneus_area x 1/(anatomy_lh_superiorparietal_area)',
#  'anatomy_lh_cuneus_area x 1/(anatomy_lh_supramarginal_area)',
#  'anatomy_lh_cuneus_area x 1/(anatomy_rh_caudalanteriorcingulate_area)',
#  'anatomy_lh_cuneus_area x 1/(anatomy_rh_caudalmiddlefrontal_area)',
#  'anatomy_lh_cuneus_area x 1/(anatomy_rh_entorhinal_area)',
#  'anatomy_lh_cuneus_area x 1/(anatomy_rh_inferiorparietal_area)',
#  'anatomy_lh_cuneus_area x 1/(anatomy_rh_inferiortemporal_area)',
#  'anatomy_lh_cuneus_area x 1/(anatomy_rh_lateralorbitofrontal_area)',
#  'anatomy_lh_cuneus_area x 1/(anatomy_rh_lingual_area)',
#  'anatomy_lh_cuneus_area x 1/(anatomy_rh_parahippocampal_area)',
#  'anatomy_lh_cuneus_area x 1/(anatomy_rh_parsopercularis_area)',
#  'anatomy_lh_cuneus_area x 1/(anatomy_rh_parstriangularis_area)',
#  'anatomy_lh_cuneus_area x 1/(anatomy_rh_pericalcarine_area)',
#  'anatomy_lh_cuneus_area x 1/(anatomy_rh_posteriorcingulate_area)',
#  'anatomy_lh_cuneus_area x 1/(anatomy_rh_superiorparietal_area)',
#  'anatomy_lh_cuneus_area x 1/(anatomy_rh_supramarginal_area)',
#  'anatomy_lh_cuneus_area x 1/(anatomy_rh_frontalpole_area)',
#  'anatomy_lh_cuneus_area x 1/(anatomy_rh_temporalpole_area)',
#  'anatomy_lh_cuneus_area x 1/(anatomy_rh_insula_area)',
#  'anatomy_lh_cuneus_area x 1/(anatomy_lh_fusiform_thickness)',
#  'anatomy_lh_cuneus_area x 1/(anatomy_lh_lateralorbitofrontal_thickness)',
#  'anatomy_lh_cuneus_area x 1/(anatomy_lh_lingual_thickness)',
#  'anatomy_lh_cuneus_area x 1/(anatomy_lh_parahippocampal_thickness)',
#  'anatomy_lh_cuneus_area x 1/(anatomy_lh_supramarginal_thickness)',
#  'anatomy_lh_cuneus_area x 1/(anatomy_lh_frontalpole_thickness)',
#  'anatomy_lh_cuneus_area x 1/(anatomy_lh_temporalpole_thickness)',
#  'anatomy_lh_cuneus_area x 1/(anatomy_rh_cuneus_thickness)',
#  'anatomy_lh_cuneus_area x 1/(anatomy_rh_entorhinal_thickness)',
#  'anatomy_lh_cuneus_area x 1/(anatomy_rh_fusiform_thickness)',
#  'anatomy_lh_cuneus_area x 1/(anatomy_rh_isthmuscingulate_thickness)',
#  'anatomy_lh_cuneus_area x 1/(anatomy_rh_lateralorbitofrontal_thickness)',
#  'anatomy_lh_cuneus_area x 1/(anatomy_rh_rostralmiddlefrontal_thickness)',
#  'anatomy_lh_cuneus_area x 1/(anatomy_Left-Lateral-Ventricle)',
#  'anatomy_lh_cuneus_area x 1/(anatomy_Left-Inf-Lat-Vent)',
#  'anatomy_lh_cuneus_area x 1/(anatomy_Left-Cerebellum-White-Matter)',
#  'anatomy_lh_cuneus_area x 1/(anatomy_Left-Cerebellum-Cortex)',
#  'anatomy_lh_cuneus_area x 1/(anatomy_Left-Pallidum)',
#  'anatomy_lh_cuneus_area x 1/(anatomy_3rd-Ventricle)',
#  'anatomy_lh_cuneus_area x 1/(anatomy_4th-Ventricle)',
#  'anatomy_lh_cuneus_area x 1/(anatomy_Left-Amygdala)',
#  'anatomy_lh_cuneus_area x 1/(anatomy_Left-Accumbens-area)',
#  'anatomy_lh_cuneus_area x 1/(anatomy_Left-VentralDC)',
#  'anatomy_lh_cuneus_area x 1/(anatomy_Left-vessel)',
#  'anatomy_lh_cuneus_area x 1/(anatomy_Left-choroid-plexus)',
#  'anatomy_lh_cuneus_area x 1/(anatomy_Right-Amygdala)',
#  'anatomy_lh_cuneus_area x 1/(anatomy_Right-Accumbens-area)',
#  'anatomy_lh_cuneus_area x 1/(anatomy_WM-hypointensities)',
#  'anatomy_lh_cuneus_area x 1/(anatomy_CC_Central)',
#  'anatomy_lh_cuneus_area x 1/(anatomy_lhCerebralWhiteMatterVol)',
#  'anatomy_lh_cuneus_area x 1/(anatomy_CerebralWhiteMatterVol)',
#  'anatomy_lh_cuneus_area x 1/(anatomy_MaskVol)',
#  'anatomy_lh_cuneus_area x 1/(anatomy_SurfaceHoles)',
#  'anatomy_lh_cuneus_area x 1/((anatomy_Left-Putamen - anatomy_Right-Putamen))',
#  'anatomy_lh_cuneus_area x 1/((anatomy_lhCortexVol - anatomy_rhCortexVol))',
#  'anatomy_lh_cuneus_area x 1/((anatomy_lhSurfaceHoles - anatomy_rhSurfaceHoles))',
#  'anatomy_lh_cuneus_area x 1/((anatomy_lh_MeanThickness_thickness - anatomy_rh_MeanThickness_thickness))',
#  'anatomy_lh_cuneus_area x 1/((anatomy_lh_inferiorparietal_area - anatomy_rh_inferiorparietal_area))',
#  'anatomy_lh_cuneus_area x 1/((anatomy_lh_inferiorparietal_thickness - anatomy_rh_inferiorparietal_thickness))',
#  'anatomy_lh_cuneus_area x 1/((anatomy_lh_medialorbitofrontal_area - anatomy_rh_medialorbitofrontal_area))',
#  'anatomy_lh_cuneus_area x 1/((anatomy_lh_parsopercularis_thickness - anatomy_rh_parsopercularis_thickness))',
#  'anatomy_lh_cuneus_area x 1/((anatomy_lh_pericalcarine_thickness - anatomy_rh_pericalcarine_thickness))',
#  'anatomy_lh_cuneus_area x 1/((anatomy_lh_posteriorcingulate_area - anatomy_rh_posteriorcingulate_area))',
#  'anatomy_lh_cuneus_area x 1/((anatomy_lh_precentral_thickness - anatomy_rh_precentral_thickness))',
#  'anatomy_lh_cuneus_area x 1/((anatomy_lh_rostralmiddlefrontal_area - anatomy_rh_rostralmiddlefrontal_area))',
#  'anatomy_lh_cuneus_area x 1/((anatomy_lh_rostralmiddlefrontal_thickness - anatomy_rh_rostralmiddlefrontal_thickness))',
#  'anatomy_lh_cuneus_area x 1/((anatomy_lh_superiortemporal_area - anatomy_rh_superiortemporal_area))',
#  'anatomy_lh_cuneus_area x 1/((anatomy_lh_temporalpole_area - anatomy_rh_temporalpole_area))',
#  'anatomy_lh_cuneus_area x 1/((anatomy_TotalGrayVol - anatomy_CortexVol))',
#  'anatomy_lh_cuneus_area x 1/(participants_age)',
#  'anatomy_lh_entorhinal_area x anatomy_lh_fusiform_area',
#  'anatomy_lh_entorhinal_area x anatomy_lh_lateraloccipital_area',
#  'anatomy_lh_entorhinal_area x anatomy_lh_lingual_area',
#  'anatomy_lh_entorhinal_area x anatomy_lh_medialorbitofrontal_area',
#  'anatomy_lh_entorhinal_area x anatomy_lh_pericalcarine_area',
#  'anatomy_lh_entorhinal_area x anatomy_lh_postcentral_area',
#  'anatomy_lh_entorhinal_area x anatomy_lh_posteriorcingulate_area',
#  'anatomy_lh_entorhinal_area x anatomy_lh_precentral_area',
#  'anatomy_lh_entorhinal_area x anatomy_lh_precuneus_area',
#  'anatomy_lh_entorhinal_area x anatomy_lh_rostralanteriorcingulate_area',
#  'anatomy_lh_entorhinal_area x anatomy_lh_superiorfrontal_area',
#  'anatomy_lh_entorhinal_area x anatomy_lh_superiorparietal_area',
#  'anatomy_lh_entorhinal_area x anatomy_lh_supramarginal_area',
#  'anatomy_lh_entorhinal_area x anatomy_lh_temporalpole_area',
#  'anatomy_lh_entorhinal_area x anatomy_rh_bankssts_area',
#  'anatomy_lh_entorhinal_area x anatomy_rh_caudalmiddlefrontal_area',
#  'anatomy_lh_entorhinal_area x anatomy_rh_cuneus_area',
#  'anatomy_lh_entorhinal_area x anatomy_rh_fusiform_area',
#  'anatomy_lh_entorhinal_area x anatomy_rh_lateralorbitofrontal_area',
#  'anatomy_lh_entorhinal_area x anatomy_rh_medialorbitofrontal_area',
#  'anatomy_lh_entorhinal_area x anatomy_rh_paracentral_area',
#  'anatomy_lh_entorhinal_area x anatomy_rh_postcentral_area',
#  'anatomy_lh_entorhinal_area x anatomy_rh_precentral_area',
#  'anatomy_lh_entorhinal_area x anatomy_rh_precuneus_area',
#  'anatomy_lh_entorhinal_area x anatomy_rh_superiorfrontal_area',
#  'anatomy_lh_entorhinal_area x anatomy_rh_superiorparietal_area',
#  'anatomy_lh_entorhinal_area x anatomy_rh_supramarginal_area',
#  'anatomy_lh_entorhinal_area x anatomy_rh_frontalpole_area',
#  'anatomy_lh_entorhinal_area x anatomy_rh_temporalpole_area',
#  'anatomy_lh_entorhinal_area x anatomy_lh_caudalanteriorcingulate_thickness',
#  'anatomy_lh_entorhinal_area x anatomy_lh_entorhinal_thickness',
#  'anatomy_lh_entorhinal_area x anatomy_lh_postcentral_thickness',
#  'anatomy_lh_entorhinal_area x anatomy_lh_posteriorcingulate_thickness',
#  'anatomy_lh_entorhinal_area x anatomy_lh_frontalpole_thickness',
#  'anatomy_lh_entorhinal_area x anatomy_lh_temporalpole_thickness',
#  'anatomy_lh_entorhinal_area x anatomy_rh_caudalmiddlefrontal_thickness',
#  'anatomy_lh_entorhinal_area x anatomy_rh_cuneus_thickness',
#  'anatomy_lh_entorhinal_area x anatomy_rh_entorhinal_thickness',
#  'anatomy_lh_entorhinal_area x anatomy_rh_isthmuscingulate_thickness',
#  'anatomy_lh_entorhinal_area x anatomy_rh_parsopercularis_thickness',
#  'anatomy_lh_entorhinal_area x anatomy_rh_postcentral_thickness',
#  'anatomy_lh_entorhinal_area x anatomy_rh_rostralanteriorcingulate_thickness',
#  'anatomy_lh_entorhinal_area x anatomy_Left-Lateral-Ventricle',
#  'anatomy_lh_entorhinal_area x anatomy_Left-Inf-Lat-Vent',
#  'anatomy_lh_entorhinal_area x anatomy_Left-Cerebellum-White-Matter',
#  'anatomy_lh_entorhinal_area x anatomy_Left-Thalamus-Proper',
#  'anatomy_lh_entorhinal_area x anatomy_Left-Caudate',
#  'anatomy_lh_entorhinal_area x anatomy_Left-Putamen',
#  'anatomy_lh_entorhinal_area x anatomy_Left-Pallidum',
#  'anatomy_lh_entorhinal_area x anatomy_3rd-Ventricle',
#  'anatomy_lh_entorhinal_area x anatomy_4th-Ventricle',
#  'anatomy_lh_entorhinal_area x anatomy_Brain-Stem',
#  'anatomy_lh_entorhinal_area x anatomy_Left-Hippocampus',
#  'anatomy_lh_entorhinal_area x anatomy_Left-Accumbens-area',
#  'anatomy_lh_entorhinal_area x anatomy_Left-VentralDC',
#  'anatomy_lh_entorhinal_area x anatomy_Left-vessel',
#  'anatomy_lh_entorhinal_area x anatomy_Left-choroid-plexus',
#  'anatomy_lh_entorhinal_area x anatomy_Right-Lateral-Ventricle',
#  'anatomy_lh_entorhinal_area x anatomy_Right-Inf-Lat-Vent',
#  'anatomy_lh_entorhinal_area x anatomy_Right-Cerebellum-White-Matter',
#  'anatomy_lh_entorhinal_area x anatomy_Right-Thalamus-Proper',
#  'anatomy_lh_entorhinal_area x anatomy_Right-Pallidum',
#  'anatomy_lh_entorhinal_area x anatomy_Right-Hippocampus',
#  'anatomy_lh_entorhinal_area x anatomy_Right-Accumbens-area',
#  'anatomy_lh_entorhinal_area x anatomy_Right-vessel',
#  'anatomy_lh_entorhinal_area x anatomy_WM-hypointensities',
#  'anatomy_lh_entorhinal_area x anatomy_CC_Central',
#  'anatomy_lh_entorhinal_area x anatomy_BrainSegVol',
#  'anatomy_lh_entorhinal_area x anatomy_BrainSegVolNotVentSurf',
#  'anatomy_lh_entorhinal_area x anatomy_lhCortexVol',
#  'anatomy_lh_entorhinal_area x anatomy_CortexVol',
#  'anatomy_lh_entorhinal_area x anatomy_lhCerebralWhiteMatterVol',
#  'anatomy_lh_entorhinal_area x anatomy_CerebralWhiteMatterVol',
#  'anatomy_lh_entorhinal_area x anatomy_SupraTentorialVol',
#  'anatomy_lh_entorhinal_area x anatomy_SupraTentorialVolNotVent',
#  'anatomy_lh_entorhinal_area x anatomy_MaskVol',
#  'anatomy_lh_entorhinal_area x anatomy_MaskVol-to-eTIV',
#  'anatomy_lh_entorhinal_area x anatomy_lhSurfaceHoles',
#  'anatomy_lh_entorhinal_area x anatomy_SurfaceHoles',
#  'anatomy_lh_entorhinal_area x anatomy_eTIV',
#  'anatomy_lh_entorhinal_area x anatomy_BrainSegVolNotVent',
#  'anatomy_lh_entorhinal_area x (anatomy_Left-Accumbens-area - anatomy_Right-Accumbens-area)',
#  ...]

# %%
from sklearn.base import BaseEstimator
from sklearn.base import TransformerMixin
from sklearn.base import BaseEstimator
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline

n_jobs=1
seed = 42


class FeatureExtractor(BaseEstimator, TransformerMixin):
        
    def fit(self, X_df, y):
        return self

    def transform(self, X_df):
        # get only the anatomical information
        return X_df
        

class Classifier(BaseEstimator):
    def __init__(self):
        self.clf = make_pipeline(StandardScaler(), 
                                 LogisticRegression(random_state=seed))

    def fit(self, X, y):
        self.clf.fit(X, y)
        return self
        
    def predict(self, X):
        return self.clf.predict(X)

    def predict_proba(self, X):
        return self.clf.predict_proba(X)

# %%
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import cross_validate, StratifiedShuffleSplit


def evaluation(X, y):
    pipe = make_pipeline(FeatureExtractor(), Classifier())
    cv = StratifiedShuffleSplit(n_splits=10, test_size=0.5, random_state=42).split(X, y)
    results = cross_validate(pipe, X, y, scoring=['roc_auc', 'accuracy'], cv=cv,
                             verbose=1, return_train_score=True,
                             n_jobs=1)
    
    return results


from problem import get_cv


def original_evaluation(X, y):
    pipe = make_pipeline(FeatureExtractor(), Classifier())
    cv = get_cv(X, y)
    results = cross_validate(pipe, X, y, scoring=['roc_auc', 'accuracy'], cv=cv,
                             verbose=1, return_train_score=True,
                             n_jobs=1)    
    return results

# %% [markdown]
# Check `corr_selected_columns`

# %%
import numpy as np

results = evaluation(data2[corr_selected_columns], data2['target'])

print("Training score ROC-AUC: {:.3f} +- {:.3f}".format(np.mean(results['train_roc_auc']),
                                                        np.std(results['train_roc_auc'])))
print("Validation score ROC-AUC: {:.3f} +- {:.3f} \n".format(np.mean(results['test_roc_auc']),
                                                          np.std(results['test_roc_auc'])))

print("Training score accuracy: {:.3f} +- {:.3f}".format(np.mean(results['train_accuracy']),
                                                         np.std(results['train_accuracy'])))
print("Validation score accuracy: {:.3f} +- {:.3f}".format(np.mean(results['test_accuracy']),
                                                           np.std(results['test_accuracy'])))
# Out:
# Training score ROC-AUC: 1.000 +- 0.000
# Validation score ROC-AUC: 0.683 +- 0.030
#
# Training score accuracy: 1.000 +- 0.000
# Validation score accuracy: 0.633 +- 0.025
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:   44.1s finished

# %% [markdown]
# ```
# Training score ROC-AUC: 1.000 +- 0.000
# Validation score ROC-AUC: 0.672 +- 0.019
#
# Training score accuracy: 1.000 +- 0.000
# Validation score accuracy: 0.627 +- 0.020
# ```

# %% [markdown]
# ### Feature importance of extracted features

# %%
from sklearn.feature_selection import SelectFromModel

pipe = make_pipeline(StandardScaler(), LogisticRegression(C=100, n_jobs=1, random_state=seed))
log_reg = pipe.named_steps['logisticregression']
feature_selection = SelectFromModel(log_reg, prefit=True, threshold="4.0*mean")

# %%
pipe.fit(data2[corr_selected_columns], data2['target'])
# Out:
# Pipeline(memory=None,
#      steps=[('standardscaler', StandardScaler(copy=True, with_mean=True, with_std=True)), ('logisticregression', LogisticRegression(C=100, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=42, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False))])

# %%
np_corr_selected_columns = np.array(corr_selected_columns)

# %%
selected_corr_columns = feature_selection.transform(np_corr_selected_columns[None, :])[0].tolist()

# %%
len(selected_corr_columns), selected_corr_columns[:10], selected_corr_columns[-10:]
# Out:
# (343,
#  ['participants_sex',
#   '1/(anatomy_lh_rostralanteriorcingulate_area)',
#   '1/(anatomy_lh_temporalpole_area)',
#   '1/(anatomy_rh_caudalanteriorcingulate_area)',
#   '1/(anatomy_rh_inferiorparietal_area)',
#   '1/(anatomy_rh_isthmuscingulate_area)',
#   '1/(anatomy_rh_parstriangularis_area)',
#   '1/(anatomy_rh_rostralanteriorcingulate_area)',
#   '1/(anatomy_Left-Lateral-Ventricle)',
#   '1/(anatomy_3rd-Ventricle)'],
#  ['(anatomy_lh_rostralmiddlefrontal_area - anatomy_rh_rostralmiddlefrontal_area) x (anatomy_lh_temporalpole_thickness - anatomy_rh_temporalpole_thickness)',
#   '(anatomy_lh_rostralmiddlefrontal_area - anatomy_rh_rostralmiddlefrontal_area) x (anatomy_lh_transversetemporal_area - anatomy_rh_transversetemporal_area)',
#   '(anatomy_lh_rostralmiddlefrontal_thickness - anatomy_rh_rostralmiddlefrontal_thickness) x (anatomy_lh_superiortemporal_thickness - anatomy_rh_superiortemporal_thickness)',
#   '(anatomy_lh_rostralmiddlefrontal_thickness - anatomy_rh_rostralmiddlefrontal_thickness) x (anatomy_lh_supramarginal_thickness - anatomy_rh_supramarginal_thickness)',
#   '(anatomy_lh_superiorfrontal_area - anatomy_rh_superiorfrontal_area) x (anatomy_lh_temporalpole_area - anatomy_rh_temporalpole_area)',
#   '(anatomy_lh_superiorfrontal_thickness - anatomy_rh_superiorfrontal_thickness) x (anatomy_lh_temporalpole_area - anatomy_rh_temporalpole_area)',
#   '(anatomy_lh_superiorparietal_thickness - anatomy_rh_superiorparietal_thickness) x (anatomy_lh_transversetemporal_thickness - anatomy_rh_transversetemporal_thickness)',
#   '(anatomy_lh_supramarginal_area - anatomy_rh_supramarginal_area) x (anatomy_lh_temporalpole_area - anatomy_rh_temporalpole_area)',
#   '(anatomy_lh_supramarginal_thickness - anatomy_rh_supramarginal_thickness) x (anatomy_lh_transversetemporal_area - anatomy_rh_transversetemporal_area)',
#   '(anatomy_lh_transversetemporal_area - anatomy_rh_transversetemporal_area) x (anatomy_lh_transversetemporal_thickness - anatomy_rh_transversetemporal_thickness)'])

# %%
# log_reg = pipe.named_steps['logisticregression']

# coef = log_reg.coef_.ravel()
# positive_coefficients_2 = np.argsort(coef)
# negative_coefficients_2 = np.argsort(coef)

# coef.min(), coef.max(), np.abs(coef).min()

# sns.distplot(coef, kde=False)

# n_top_features = 400

# positive_coefficients = positive_coefficients_2[-n_top_features:]
# negative_coefficients = negative_coefficients_2[:n_top_features]
# interesting_coefficients = np.hstack([negative_coefficients, positive_coefficients])

# top_corr_selected_columns = np.array(corr_selected_columns)[interesting_coefficients].tolist()

# %% [markdown]
# ## Train a linear model

# %%
from sklearn.base import BaseEstimator
from sklearn.base import TransformerMixin
from sklearn.base import BaseEstimator
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline

n_jobs=1
seed = 42


class FeatureExtractor(BaseEstimator, TransformerMixin):
        
    def fit(self, X_df, y):
        return self

    def transform(self, X_df):
        # get only the anatomical information
        return X_df
        

class Classifier(BaseEstimator):
    def __init__(self):
        self.clf = make_pipeline(StandardScaler(), 
                                 LogisticRegression(random_state=seed))

    def fit(self, X, y):
        self.clf.fit(X, y)
        return self
        
    def predict(self, X):
        return self.clf.predict(X)

    def predict_proba(self, X):
        return self.clf.predict_proba(X)

# %% [markdown]
# Check `corr_selected_columns`

# %%
import numpy as np

results = evaluation(data2[selected_corr_columns], data2['target'])

print("Training score ROC-AUC: {:.3f} +- {:.3f}".format(np.mean(results['train_roc_auc']),
                                                        np.std(results['train_roc_auc'])))
print("Validation score ROC-AUC: {:.3f} +- {:.3f} \n".format(np.mean(results['test_roc_auc']),
                                                          np.std(results['test_roc_auc'])))

print("Training score accuracy: {:.3f} +- {:.3f}".format(np.mean(results['train_accuracy']),
                                                         np.std(results['train_accuracy'])))
print("Validation score accuracy: {:.3f} +- {:.3f}".format(np.mean(results['test_accuracy']),
                                                           np.std(results['test_accuracy'])))
# Out:
# Training score ROC-AUC: 1.000 +- 0.000
# Validation score ROC-AUC: 0.734 +- 0.015
#
# Training score accuracy: 1.000 +- 0.000
# Validation score accuracy: 0.672 +- 0.016
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:    0.6s finished

# %% [markdown]
# A reference with feature ^ 2
# ```
# Training score ROC-AUC: 1.000 +- 0.000
# Validation score ROC-AUC: 0.637 +- 0.014
#
# Training score accuracy: 1.000 +- 0.000
# Validation score accuracy: 0.604 +- 0.014
# ```

# %%
from sklearn.base import BaseEstimator
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LogisticRegressionCV, LogisticRegression
seed = 90
        

class Classifier(BaseEstimator):
    def __init__(self):
        self.clf = None

    def fit(self, X, y):
        
        pipe_cv = make_pipeline(StandardScaler(), 
                                LogisticRegressionCV(n_jobs=8, scoring="roc_auc", random_state=seed))
        pipe_cv.fit(X, y)
        best_C = pipe_cv.named_steps['logisticregressioncv'].C_[0]
        self.clf = make_pipeline(StandardScaler(), LogisticRegression(C=best_C, random_state=seed))
        self.clf.fit(X, y)
        return self
        
    def predict(self, X):
        return self.clf.predict(X)

    def predict_proba(self, X):
        return self.clf.predict_proba(X)

# %%
import numpy as np

results = evaluation(data2[selected_corr_columns], data2['target'])

print("Training score ROC-AUC: {:.3f} +- {:.3f}".format(np.mean(results['train_roc_auc']),
                                                        np.std(results['train_roc_auc'])))
print("Validation score ROC-AUC: {:.3f} +- {:.3f} \n".format(np.mean(results['test_roc_auc']),
                                                          np.std(results['test_roc_auc'])))

print("Training score accuracy: {:.3f} +- {:.3f}".format(np.mean(results['train_accuracy']),
                                                         np.std(results['train_accuracy'])))
print("Validation score accuracy: {:.3f} +- {:.3f}".format(np.mean(results['test_accuracy']),
                                                           np.std(results['test_accuracy'])))
# Out:
# Training score ROC-AUC: 0.969 +- 0.021
# Validation score ROC-AUC: 0.751 +- 0.018
#
# Training score accuracy: 0.908 +- 0.037
# Validation score accuracy: 0.684 +- 0.014
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:    4.9s finished

# %% [markdown]
# ```
# Training score ROC-AUC: 0.969 +- 0.021
# Validation score ROC-AUC: 0.751 +- 0.018
#
# Training score accuracy: 0.908 +- 0.037
# Validation score accuracy: 0.684 +- 0.014
#
# ```

# %%
def visualize_coefficients(classifier, feature_names, n_top_features=25):
    # get coefficients with large absolute values 
    coef = classifier.coef_.ravel()
    positive_coefficients = np.argsort(coef)[-n_top_features:]
    negative_coefficients = np.argsort(coef)[:n_top_features]
    interesting_coefficients = np.hstack([negative_coefficients, positive_coefficients])
    # plot them
    plt.figure(figsize=(20, 10))
    colors = ["red" if c < 0 else "blue" for c in coef[interesting_coefficients]]
    plt.bar(np.arange(2 * n_top_features), coef[interesting_coefficients], color=colors)
    if feature_names is not None:
        feature_names = np.array(feature_names)
        plt.xticks(np.arange(1, 1 + 2 * n_top_features), feature_names[interesting_coefficients], rotation=60, ha="right");

# %%
from sklearn.base import BaseEstimator
from sklearn.base import TransformerMixin
from sklearn.base import BaseEstimator
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline

n_jobs=1
seed = 42


class FeatureExtractor(BaseEstimator, TransformerMixin):
        
    def fit(self, X_df, y):
        return self

    def transform(self, X_df):
        # get only the anatomical information
        return X_df
        

class Classifier(BaseEstimator):
    def __init__(self):
        self.clf = make_pipeline(StandardScaler(), 
                                 LogisticRegression(random_state=seed))

    def fit(self, X, y):
        self.clf.fit(X, y)
        return self
        
    def predict(self, X):
        return self.clf.predict(X)

    def predict_proba(self, X):
        return self.clf.predict_proba(X)

# %% [markdown]
# ### Feature importance of Corr selected features

# %%
pipe = make_pipeline(FeatureExtractor(), Classifier())
pipe.fit(data2[corr_selected_columns], data2['target'])
# Out:
# Pipeline(memory=None,
#      steps=[('featureextractor', FeatureExtractor()), ('classifier', Classifier())])

# %%
log_reg2 = pipe.named_steps['classifier'].clf.named_steps['logisticregression']

# %%
visualize_coefficients(log_reg2, feature_names=corr_selected_columns, n_top_features=40)

# %%
coef2 = log_reg2.coef_.ravel()

# %%
coef2.min(), coef2.max(), np.abs(coef2).min()
# Out:
# (-0.6070593951213107, 0.6559933752839194, 9.996404120298061e-06)

# %%
sns.distplot(coef2, kde=False)
# Out:
# /opt/conda/envs/rampwf/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
neg_threshold = 0.12 * coef2.min()
pos_threshold = 0.12 * coef2.max()
neg_threshold, pos_threshold
# Out:
# (-0.07284712741455728, 0.07871920503407033)

# %%
positive_coefficients = np.where(coef2 > pos_threshold)[0]
negative_coefficients = np.where(coef2 < neg_threshold)[0]

# %%
len(positive_coefficients), len(negative_coefficients)
# Out:
# (479, 717)

# %%
# n_top_features = 400
# positive_coefficients = positive_coefficients_2[-n_top_features:]
# negative_coefficients = negative_coefficients_2[:n_top_features]

interesting_coefficients = np.hstack([negative_coefficients, positive_coefficients])
top_corr_selected_columns = np.array(corr_selected_columns)[interesting_coefficients].tolist()

# %%
from sklearn.base import BaseEstimator
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LogisticRegressionCV, LogisticRegression
from sklearn.model_selection import StratifiedKFold

seed = 90
        

class Classifier(BaseEstimator):
    def __init__(self):
        self.clf = None

    def fit(self, X, y):
        
        pipe_cv = make_pipeline(StandardScaler(), 
                                LogisticRegressionCV(n_jobs=8,
                                                     # cv=StratifiedKFold(n_splits=5, random_state=seed),
                                                     scoring="roc_auc", 
                                                     random_state=seed))
        pipe_cv.fit(X, y)
        best_C = pipe_cv.named_steps['logisticregressioncv'].C_[0]
        self.clf = make_pipeline(StandardScaler(), LogisticRegression(C=best_C, random_state=seed))
        self.clf.fit(X, y)
        return self
        
    def predict(self, X):
        return self.clf.predict(X)

    def predict_proba(self, X):
        return self.clf.predict_proba(X)

# %%
results = evaluation(data2[top_corr_selected_columns], data2['target'])

print("Training score ROC-AUC: {:.3f} +- {:.3f}".format(np.mean(results['train_roc_auc']),
                                                        np.std(results['train_roc_auc'])))
print("Validation score ROC-AUC: {:.3f} +- {:.3f} \n".format(np.mean(results['test_roc_auc']),
                                                          np.std(results['test_roc_auc'])))

print("Training score accuracy: {:.3f} +- {:.3f}".format(np.mean(results['train_accuracy']),
                                                         np.std(results['train_accuracy'])))
print("Validation score accuracy: {:.3f} +- {:.3f}".format(np.mean(results['test_accuracy']),
                                                           np.std(results['test_accuracy'])))
# Out:
# Training score ROC-AUC: 1.000 +- 0.000
# Validation score ROC-AUC: 0.764 +- 0.022
#
# Training score accuracy: 0.999 +- 0.001
# Validation score accuracy: 0.694 +- 0.024
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:    8.6s finished

# %% [markdown]
# **config 2**
#
# ```
# anatomy select in [1, 2]
# corr12_inv_approx = corr12_inv_.apply(lambda x: round(x, 5))
#
# filtered_corr12_inv_ = corr12_inv_approx[~corr12_inv_approx.duplicated()]
# filtered_corr12_inv_ = filtered_corr12_inv_[filtered_corr12_inv_.abs() > 0.017]
# ```
#
# (-0.07284712741455728, 0.07871920503407033)
# ```
# Training score ROC-AUC: 1.000 +- 0.000
# Validation score ROC-AUC: 0.764 +- 0.022
#
# Training score accuracy: 0.999 +- 0.001
# Validation score accuracy: 0.694 +- 0.024
# ```
#
#
#
#
# **config 1**
#
# ```
# anatomy select < 2
# corr12_inv_approx = corr12_inv_.apply(lambda x: round(x, 5))
#
# filtered_corr12_inv_ = corr12_inv_approx[~corr12_inv_approx.duplicated()]
# filtered_corr12_inv_ = filtered_corr12_inv_[filtered_corr12_inv_.abs() > 0.03]
# ```
#
# (-0.08605396730502125, 0.07733905985162687)
# ```
# Training score ROC-AUC: 1.000 +- 0.000
# Validation score ROC-AUC: 0.765 +- 0.009
#
# Training score accuracy: 0.999 +- 0.002
# Validation score accuracy: 0.697 +- 0.010
# ```

# %%
results = original_evaluation(data2[top_corr_selected_columns], data2['target'])

print("Training score ROC-AUC: {:.3f} +- {:.3f}".format(np.mean(results['train_roc_auc']),
                                                        np.std(results['train_roc_auc'])))
print("Validation score ROC-AUC: {:.3f} +- {:.3f} \n".format(np.mean(results['test_roc_auc']),
                                                          np.std(results['test_roc_auc'])))

print("Training score accuracy: {:.3f} +- {:.3f}".format(np.mean(results['train_accuracy']),
                                                         np.std(results['train_accuracy'])))
print("Validation score accuracy: {:.3f} +- {:.3f}".format(np.mean(results['test_accuracy']),
                                                           np.std(results['test_accuracy'])))
# Out:
# Training score ROC-AUC: 1.000 +- 0.000
# Validation score ROC-AUC: 0.844 +- 0.023
#
# Training score accuracy: 1.000 +- 0.000
# Validation score accuracy: 0.763 +- 0.030
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:   11.1s finished

# %% [markdown]
# **config 2**
# ```
# Training score ROC-AUC: 1.000 +- 0.000
# Validation score ROC-AUC: 0.844 +- 0.023
#
# Training score accuracy: 1.000 +- 0.000
# Validation score accuracy: 0.763 +- 0.030
# ```
#
#
#
# **config 1**
# ```
# Training score ROC-AUC: 1.000 +- 0.000
# Validation score ROC-AUC: 0.842 +- 0.024
#
# Training score accuracy: 1.000 +- 0.000
# Validation score accuracy: 0.762 +- 0.022
# ```

# %% [markdown]
# Try SVM

# %%
from sklearn.base import BaseEstimator
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import StratifiedKFold

seed = 90
        

class Classifier(BaseEstimator):
    def __init__(self):
        self.clf = None

    def fit(self, X, y):
                
        params = {
            "C": np.logspace(-2, 5, num=12),
            "kernel": ["rbf", "linear"]
        }
        clf = SVC()
        pipe_cv = make_pipeline(StandardScaler(), 
                                GridSearchCV(clf, params, 
                                             n_jobs=8, 
                                             cv=StratifiedKFold(n_splits=5, random_state=seed),
                                             scoring="roc_auc"))
        pipe_cv.fit(X, y)
        best_params = pipe_cv.named_steps['gridsearchcv'].best_params_
        self.clf = make_pipeline(StandardScaler(), SVC(random_state=seed, probability=True, **best_params))
        self.clf.fit(X, y)
        return self
        
    def predict(self, X):
        return self.clf.predict(X)

    def predict_proba(self, X):
        return self.clf.predict_proba(X)

# %%
results = evaluation(data2[top_corr_selected_columns], data2['target'])

print("Training score ROC-AUC: {:.3f} +- {:.3f}".format(np.mean(results['train_roc_auc']),
                                                        np.std(results['train_roc_auc'])))
print("Validation score ROC-AUC: {:.3f} +- {:.3f} \n".format(np.mean(results['test_roc_auc']),
                                                          np.std(results['test_roc_auc'])))

print("Training score accuracy: {:.3f} +- {:.3f}".format(np.mean(results['train_accuracy']),
                                                         np.std(results['train_accuracy'])))
print("Validation score accuracy: {:.3f} +- {:.3f}".format(np.mean(results['test_accuracy']),
                                                           np.std(results['test_accuracy'])))
# Out:
# Training score ROC-AUC: 1.000 +- 0.000
# Validation score ROC-AUC: 0.765 +- 0.013
#
# Training score accuracy: 0.999 +- 0.004
# Validation score accuracy: 0.698 +- 0.016
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:  1.5min finished

# %% [markdown]
# 150 (0.088 Corr threshold)
# ```
# Training score ROC-AUC: 0.970 +- 0.027
# Validation score ROC-AUC: 0.765 +- 0.019
#
# Training score accuracy: 0.918 +- 0.051
# Validation score accuracy: 0.700 +- 0.017
# ```

# %% [markdown]
# 175 (0.04 Corr threshold)
# ```
# Training score ROC-AUC: 0.986 +- 0.009
# Validation score ROC-AUC: 0.812 +- 0.014
#
# Training score accuracy: 0.946 +- 0.028
# Validation score accuracy: 0.732 +- 0.012
# ```
#
# 160 (0.04 Corr threshold)
# ```
# Training score ROC-AUC: 0.985 +- 0.011
# Validation score ROC-AUC: 0.811 +- 0.009
#
# Training score accuracy: 0.944 +- 0.030
# Validation score accuracy: 0.733 +- 0.011
# ```
#
# 140 (0.04 Corr threshold)
# ```
# Training score ROC-AUC: 0.982 +- 0.012
# Validation score ROC-AUC: 0.811 +- 0.012
#
# Training score accuracy: 0.937 +- 0.029
# Validation score accuracy: 0.732 +- 0.015
# ```
#
#
# 140 (0.05 Corr threshold)
# ```
# Training score ROC-AUC: 0.979 +- 0.018
# Validation score ROC-AUC: 0.797 +- 0.006
#
# Training score accuracy: 0.933 +- 0.038
# Validation score accuracy: 0.717 +- 0.010
# ```

# %% [markdown]
# Print features as a single line

# %%
# print("[", end="")
# for f in selected_columns:
#     print("\"{}\"".format(f), end=", ")
# print("]")

# %%
# print("[", end="")
# for f in top_corr_selected_columns:
#     print("\"{}\"".format(f), end=", ")
# print("]")
